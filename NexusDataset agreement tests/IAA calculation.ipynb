# %% [markdown]
# # Offensive language annotation campaign analysis
#
# * sklearn Cohen kappa: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.cohen_kappa_score.html#sklearn.metrics.cohen_kappa_score
# * kappa's comparison: https://towardsdatascience.com/inter-rater-agreement-kappas-69cd8b91ff75
#
# Cohen's Kappa interpretation:
# ![](kappa-interpretation.png)
#
# # Script - imports and functions

# %%
# IMPORTS
import json
import glob
import re
import pandas as pd
from sklearn import metrics as sk_metrics

import warnings
warnings.filterwarnings("ignore")

# %%
def get_documents(project_path):
    # Get possible statuses from project JSON
    project_json_file = project_path + "/exportedproject18042961325071563346.json"
    project_data = json.load(open(project_json_file))

    document_statuses = set()
    documents = []
    for document in project_data["source_documents"]:
        document_statuses.add(document["state"])
        documents.append((document["name"], document["state"]))

    #print(f"Possible statuses: {document_statuses}")
    return documents

# %%
def select_document_names_by_type(documents, status_types):
    # Select documents
    document_names = [doc[0] for doc in documents if doc[1] in status_types]
    print(f"Number of documents: {len(document_names)}")
    return document_names

# %%
# Prepare annotation objects
def annotations_from_tsv_file(filename, annotation_category):
    # Second line should look as follows:
    # #T_SP=webanno.custom.Offensivelanguage|Aspect|Aspect2|Aspect3|Category|Expressiveness|Figurative|Targetlevel|Targettype
    lines = open(filename).readlines()
    
    # get annotation index
    annotation_index = 0
    tsv_header = lines[1].split("|")
    if tsv_header[0] == "#T_SP=webanno.custom.Offensivelanguage":
        annotation_index = tsv_header.index(annotation_category)-1
    else:
        # Document contains no annotations
        annotation_index = -1
        
    # get indices of new lines
    indices = [i for i, x in enumerate(lines) if x == "\n"]
    # Add last index
    indices.append(len(lines))

    # get pairs of indices to get sentences
    pair_indices = []
    for i in range(len(indices)-1):
        if abs(indices[i]-indices[i+1]) > 1: #remove duplicate new lines (beginning of document)
            pair_indices.append(indices[i:i+2])

    # get sentences
    sentences = []
    for pair in pair_indices:
        # First sentence element is always text
        sentences.append(lines[pair[0]+1:pair[1]])

    # get annotations
    annotations = []
    for sentence in sentences:
        if annotation_index == -1:
            annotations.append("None")
        else:
            annotation = sentence[1].split("\t")[3+annotation_index]
            if annotation == "_":
                annotation = "None"                        
            annotation = re.sub(r"\[.*?\]", "", annotation) # remove annotation indexes
            annotation = annotation.replace("*", "None")
            annotation = annotation.replace("|None|", "|")
            annotation = annotation.replace("None|", "")
            annotation = annotation.replace("|None", "")
            annotation = "|".join(sorted(annotation.split("|"))) # sort annotations if multiple present
            annotations.append(annotation)
        
    return annotations

# %%
# folder can be annotation or curation
def get_annotation_data_frame(document_names, project_path, folder = "annotation"):
    all_annotations = []
    # get all annotations per document
    # each annotations looks like (document_name, annotator_name, [annotations])
    for document_name in document_names:
        annotator_files = glob.glob(f"{project_path}/{folder}/{document_name}/*.tsv")

        #get annotations per document
        for annotator_file in annotator_files:
            annotator = annotator_file.split("/")[-1]
            annotations = [document_name, annotator]
            # Possible annotation categories:
            # Aspect|Aspect2|Aspect3|Category|Expressiveness|Figurative|Targetlevel|Targettype
            for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype\n"]:
                annotations.append(annotations_from_tsv_file(annotator_file, annotation_category))

            all_annotations.append(annotations)

    df = pd.DataFrame(all_annotations, columns =['Document', 'Annotator', "Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"])
    return df

# %%
def get_annotator_groups_per_document(df, verbose = True):
    groups = set()
    for group in df.groupby("Document")["Annotator"].apply(list):
        groups.add(tuple(sorted(group)))
    if verbose:
        print(f"\nGroups: \n\t{groups}\n")
    return groups

# %%
def get_cohen_kappa_score(df, annotation_category, verbose = True):

    # get all annotation labels
    annotation_labels = set()
    for annotation_data in list(df[annotation_category]):
        annotation_labels.update(annotation_data)

    if verbose:
        print(f"All read different annotation labels: \n\t{annotation_labels}\n")
    
    # get annotator groups per document
    groups= get_annotator_groups_per_document(df, verbose)

    #for row in df.groupby("Document")["Annotator"]:
    #    print(list(row[1]))
    
    # get annotation pair lists
    annotations_one = []
    annotations_two = []
    for annotations_pair in df.groupby("Document")[annotation_category].apply(list):
        if len(annotations_pair) != 2:
            raise Exception(f"More than two annotators per document: '{annotations_pair}'!")

        annotations_one.extend(annotations_pair[0])
        annotations_two.extend(annotations_pair[1])

    # both lists should be of same length
    assert len(annotations_one) == len(annotations_two)
    if verbose:
        print(f"We are comparing {len(annotations_one)} annotated sentences.")
    
    # change label values (None, 0, 1, 2, 3, ...)
    label_mapping = {"None": -1}
    cur_mapping_id = 0
    for label in annotation_labels:
        if label != "None" and label not in label_mapping:
            label_mapping[label] = cur_mapping_id
            cur_mapping_id += 1
    if verbose:
        print(f"Mapping table: {label_mapping}")
    
    # calculate IAA
    annotations_iaa_a = list(map(lambda x: label_mapping[x] if x!="None" else -1, annotations_one)) 
    annotations_iaa_b = list(map(lambda x: label_mapping[x] if x!="None" else -1, annotations_two))
    cohens = sk_metrics.cohen_kappa_score(annotations_iaa_a, annotations_iaa_b)
    return cohens, len(annotations_one)

# %% [markdown]
# # Analysis by type
#
# ## Inter-annotator agreement between annotators (in general)

# %%
# PARAMETERS
project_path = "Offensive+language+annotation+REAL_project_2022-03-09_0806"
# Possible statuses: {'CURATION_IN_PROGRESS', 'NEW', 'ANNOTATION_IN_PROGRESS', 'CURATION_FINISHED', 'ANNOTATION_FINISHED'}
status_types = ['ANNOTATION_FINISHED']

documents = get_documents(project_path)
document_names = select_document_names_by_type(documents, status_types)
df = get_annotation_data_frame(document_names, project_path, folder = "annotation")

#Eval
for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"]: 
    cohens, examples_num = get_cohen_kappa_score(df, annotation_category, verbose = False)
    print(f"Cohens kappa for {annotation_category:15} between annotator a and b: {cohens:.3f}, across {examples_num} examples.")
# Out:
# Number of documents: 567
# Cohens kappa for Aspect          between annotator a and b: 0.404, across 2712 examples.
# Cohens kappa for Aspect2         between annotator a and b: 0.254, across 2712 examples.
# Cohens kappa for Aspect3         between annotator a and b: 0.153, across 2712 examples.
# Cohens kappa for Category        between annotator a and b: 0.377, across 2712 examples.
# Cohens kappa for Expressiveness  between annotator a and b: 0.592, across 2712 examples.
# Cohens kappa for Figurative      between annotator a and b: 0.209, across 2712 examples.
# Cohens kappa for Targetlevel     between annotator a and b: 0.534, across 2712 examples.
# Cohens kappa for Targettype      between annotator a and b: 0.569, across 2712 examples.

# %% [markdown]
# ## Inter-annotator agreement between annotators

# %%
# PARAMETERS
project_path = "Offensive+language+annotation+REAL_project_2022-03-09_0806"
# Possible statuses: {'CURATION_IN_PROGRESS', 'NEW', 'ANNOTATION_IN_PROGRESS', 'CURATION_FINISHED', 'ANNOTATION_FINISHED'}
status_types = ['ANNOTATION_FINISHED']

documents = get_documents(project_path)
document_names = select_document_names_by_type(documents, status_types)

df_annotators = get_annotation_data_frame(document_names, project_path, folder = "annotation")

# get annotator pairs (groups)
groups = sorted(list(get_annotator_groups_per_document(df_annotators, verbose = False)))

for pair in groups:
    if len(pair) != 2:
        raise Exception(f"More than two annotators per document: '{annotations_pair}'!")
        
    annotator1 = pair[0]
    annotator2 = pair[1]
    
    annotator1_documents = set(df_annotators.groupby("Annotator").filter(lambda x : pd.Series([annotator1]).isin(x['Annotator']).all())["Document"])
    annotator2_documents = set(df_annotators.groupby("Annotator").filter(lambda x : pd.Series([annotator2]).isin(x['Annotator']).all())["Document"])
    annotator_documents = annotator1_documents.intersection(annotator2_documents) 
    
    df = df_annotators[df_annotators['Annotator'].isin([annotator1, annotator2])]
    df = df[df["Document"].isin(annotator_documents)]
    
    print(f"\n\nAnnotators {annotator1.replace('.tsv', ''):15} and {annotator2.replace('.tsv', ''):15} annotated {len(annotator_documents):3} documents:")
    for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"]: 
        cohens, examples_num = get_cohen_kappa_score(df, annotation_category, verbose = False)
        print(f"\t Cohens kappa for {annotation_category:15} is: {cohens:.3f}, across {examples_num} examples.")
# Out:
# Number of documents: 567
#
#
# Annotators agnieszka_borowiak@wp.pl and ana.ostroski@gmail.com annotated   7 documents:
# 	 Cohens kappa for Aspect          is: 0.523, across 54 examples.
# 	 Cohens kappa for Aspect2         is: nan, across 54 examples.
# 	 Cohens kappa for Aspect3         is: nan, across 54 examples.
# 	 Cohens kappa for Category        is: 0.222, across 54 examples.
# 	 Cohens kappa for Expressiveness  is: 0.274, across 54 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 54 examples.
# 	 Cohens kappa for Targetlevel     is: 0.523, across 54 examples.
# 	 Cohens kappa for Targettype      is: 0.523, across 54 examples.
#
#
# Annotators agnieszka_borowiak@wp.pl and ibrac@ihjj.hr   annotated  16 documents:
# 	 Cohens kappa for Aspect          is: 0.407, across 153 examples.
# 	 Cohens kappa for Aspect2         is: 0.072, across 153 examples.
# 	 Cohens kappa for Aspect3         is: 0.000, across 153 examples.
# 	 Cohens kappa for Category        is: 0.302, across 153 examples.
# 	 Cohens kappa for Expressiveness  is: 0.720, across 153 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 153 examples.
# 	 Cohens kappa for Targetlevel     is: 0.739, across 153 examples.
# 	 Cohens kappa for Targettype      is: 0.751, across 153 examples.
#
#
# Annotators agnieszka_borowiak@wp.pl and lobel.filipic@gmail.com annotated   2 documents:
# 	 Cohens kappa for Aspect          is: 0.259, across 20 examples.
# 	 Cohens kappa for Aspect2         is: 0.000, across 20 examples.
# 	 Cohens kappa for Aspect3         is: nan, across 20 examples.
# 	 Cohens kappa for Category        is: 0.444, across 20 examples.
# 	 Cohens kappa for Expressiveness  is: 0.615, across 20 examples.
# 	 Cohens kappa for Figurative      is: -0.034, across 20 examples.
# 	 Cohens kappa for Targetlevel     is: 0.286, across 20 examples.
# 	 Cohens kappa for Targettype      is: 0.455, across 20 examples.
#
#
# Annotators agnieszka_borowiak@wp.pl and marcintrk@gmail.com annotated  31 documents:
# 	 Cohens kappa for Aspect          is: 0.533, across 221 examples.
# 	 Cohens kappa for Aspect2         is: 0.285, across 221 examples.
# 	 Cohens kappa for Aspect3         is: 0.138, across 221 examples.
# 	 Cohens kappa for Category        is: 0.476, across 221 examples.
# 	 Cohens kappa for Expressiveness  is: 0.715, across 221 examples.
# 	 Cohens kappa for Figurative      is: 0.669, across 221 examples.
# 	 Cohens kappa for Targetlevel     is: 0.588, across 221 examples.
# 	 Cohens kappa for Targettype      is: 0.587, across 221 examples.
#
#
# Annotators agnieszka_borowiak@wp.pl and paul.wilson@uni.lodz.pl annotated  11 documents:
# 	 Cohens kappa for Aspect          is: 0.156, across 55 examples.
# 	 Cohens kappa for Aspect2         is: 0.195, across 55 examples.
# 	 Cohens kappa for Aspect3         is: 0.065, across 55 examples.
# 	 Cohens kappa for Category        is: 0.109, across 55 examples.
# 	 Cohens kappa for Expressiveness  is: 0.229, across 55 examples.
# 	 Cohens kappa for Figurative      is: 0.274, across 55 examples.
# 	 Cohens kappa for Targetlevel     is: 0.194, across 55 examples.
# 	 Cohens kappa for Targettype      is: 0.266, across 55 examples.
#
#
# Annotators ana.ostroski@gmail.com and ibrac@ihjj.hr   annotated  54 documents:
# 	 Cohens kappa for Aspect          is: 0.510, across 214 examples.
# 	 Cohens kappa for Aspect2         is: 0.319, across 214 examples.
# 	 Cohens kappa for Aspect3         is: 0.198, across 214 examples.
# 	 Cohens kappa for Category        is: 0.384, across 214 examples.
# 	 Cohens kappa for Expressiveness  is: 0.631, across 214 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 214 examples.
# 	 Cohens kappa for Targetlevel     is: 0.631, across 214 examples.
# 	 Cohens kappa for Targettype      is: 0.671, across 214 examples.
#
#
# Annotators ana.ostroski@gmail.com and kristina.despot@gmail.com annotated   3 documents:
# 	 Cohens kappa for Aspect          is: 0.211, across 21 examples.
# 	 Cohens kappa for Aspect2         is: 0.000, across 21 examples.
# 	 Cohens kappa for Aspect3         is: nan, across 21 examples.
# 	 Cohens kappa for Category        is: 0.157, across 21 examples.
# 	 Cohens kappa for Expressiveness  is: 0.219, across 21 examples.
# 	 Cohens kappa for Figurative      is: -0.031, across 21 examples.
# 	 Cohens kappa for Targetlevel     is: 0.172, across 21 examples.
# 	 Cohens kappa for Targettype      is: 0.135, across 21 examples.
#
#
# Annotators ana.ostroski@gmail.com and lobel.filipic@gmail.com annotated   6 documents:
# 	 Cohens kappa for Aspect          is: 0.313, across 23 examples.
# 	 Cohens kappa for Aspect2         is: 0.313, across 23 examples.
# 	 Cohens kappa for Aspect3         is: nan, across 23 examples.
# 	 Cohens kappa for Category        is: 0.652, across 23 examples.
# 	 Cohens kappa for Expressiveness  is: 0.646, across 23 examples.
# 	 Cohens kappa for Figurative      is: nan, across 23 examples.
# 	 Cohens kappa for Targetlevel     is: 0.646, across 23 examples.
# 	 Cohens kappa for Targettype      is: 0.652, across 23 examples.
#
#
# Annotators ana.ostroski@gmail.com and marcintrk@gmail.com annotated  12 documents:
# 	 Cohens kappa for Aspect          is: 0.644, across 40 examples.
# 	 Cohens kappa for Aspect2         is: 0.138, across 40 examples.
# 	 Cohens kappa for Aspect3         is: nan, across 40 examples.
# 	 Cohens kappa for Category        is: 0.398, across 40 examples.
# 	 Cohens kappa for Expressiveness  is: 0.737, across 40 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 40 examples.
# 	 Cohens kappa for Targetlevel     is: 0.530, across 40 examples.
# 	 Cohens kappa for Targettype      is: 0.578, across 40 examples.
#
#
# Annotators ana.ostroski@gmail.com and navratilova@ped.muni.cz annotated   3 documents:
# 	 Cohens kappa for Aspect          is: 0.318, across 10 examples.
# 	 Cohens kappa for Aspect2         is: 0.000, across 10 examples.
# 	 Cohens kappa for Aspect3         is: nan, across 10 examples.
# 	 Cohens kappa for Category        is: 0.318, across 10 examples.
# 	 Cohens kappa for Expressiveness  is: 0.286, across 10 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 10 examples.
# 	 Cohens kappa for Targetlevel     is: 0.286, across 10 examples.
# 	 Cohens kappa for Targettype      is: 0.333, across 10 examples.
#
#
# Annotators ana.ostroski@gmail.com and paul.wilson@uni.lodz.pl annotated  11 documents:
# 	 Cohens kappa for Aspect          is: 0.143, across 52 examples.
# 	 Cohens kappa for Aspect2         is: 0.296, across 52 examples.
# 	 Cohens kappa for Aspect3         is: 0.239, across 52 examples.
# 	 Cohens kappa for Category        is: 0.080, across 52 examples.
# 	 Cohens kappa for Expressiveness  is: 0.198, across 52 examples.
# 	 Cohens kappa for Figurative      is: 0.073, across 52 examples.
# 	 Cohens kappa for Targetlevel     is: 0.123, across 52 examples.
# 	 Cohens kappa for Targettype      is: 0.142, across 52 examples.
#
#
# Annotators ibrac@ihjj.hr   and lobel.filipic@gmail.com annotated  58 documents:
# 	 Cohens kappa for Aspect          is: 0.445, across 330 examples.
# 	 Cohens kappa for Aspect2         is: 0.377, across 330 examples.
# 	 Cohens kappa for Aspect3         is: 0.237, across 330 examples.
# 	 Cohens kappa for Category        is: 0.446, across 330 examples.
# 	 Cohens kappa for Expressiveness  is: 0.628, across 330 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 330 examples.
# 	 Cohens kappa for Targetlevel     is: 0.570, across 330 examples.
# 	 Cohens kappa for Targettype      is: 0.545, across 330 examples.
#
#
# Annotators ibrac@ihjj.hr   and marcintrk@gmail.com annotated  97 documents:
# 	 Cohens kappa for Aspect          is: 0.462, across 472 examples.
# 	 Cohens kappa for Aspect2         is: 0.281, across 472 examples.
# 	 Cohens kappa for Aspect3         is: 0.162, across 472 examples.
# 	 Cohens kappa for Category        is: 0.366, across 472 examples.
# 	 Cohens kappa for Expressiveness  is: 0.568, across 472 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 472 examples.
# 	 Cohens kappa for Targetlevel     is: 0.464, across 472 examples.
# 	 Cohens kappa for Targettype      is: 0.584, across 472 examples.
#
#
# Annotators ibrac@ihjj.hr   and navratilova@ped.muni.cz annotated  22 documents:
# 	 Cohens kappa for Aspect          is: 0.191, across 102 examples.
# 	 Cohens kappa for Aspect2         is: 0.092, across 102 examples.
# 	 Cohens kappa for Aspect3         is: 0.000, across 102 examples.
# 	 Cohens kappa for Category        is: 0.175, across 102 examples.
# 	 Cohens kappa for Expressiveness  is: 0.324, across 102 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 102 examples.
# 	 Cohens kappa for Targetlevel     is: 0.363, across 102 examples.
# 	 Cohens kappa for Targettype      is: 0.345, across 102 examples.
#
#
# Annotators ibrac@ihjj.hr   and paul.wilson@uni.lodz.pl annotated  10 documents:
# 	 Cohens kappa for Aspect          is: 0.247, across 96 examples.
# 	 Cohens kappa for Aspect2         is: 0.386, across 96 examples.
# 	 Cohens kappa for Aspect3         is: 0.211, across 96 examples.
# 	 Cohens kappa for Category        is: 0.214, across 96 examples.
# 	 Cohens kappa for Expressiveness  is: 0.385, across 96 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 96 examples.
# 	 Cohens kappa for Targetlevel     is: 0.470, across 96 examples.
# 	 Cohens kappa for Targettype      is: 0.451, across 96 examples.
#
#
# Annotators lobel.filipic@gmail.com and marcintrk@gmail.com annotated  99 documents:
# 	 Cohens kappa for Aspect          is: 0.341, across 568 examples.
# 	 Cohens kappa for Aspect2         is: 0.325, across 568 examples.
# 	 Cohens kappa for Aspect3         is: 0.197, across 568 examples.
# 	 Cohens kappa for Category        is: 0.496, across 568 examples.
# 	 Cohens kappa for Expressiveness  is: 0.652, across 568 examples.
# 	 Cohens kappa for Figurative      is: 0.028, across 568 examples.
# 	 Cohens kappa for Targetlevel     is: 0.634, across 568 examples.
# 	 Cohens kappa for Targettype      is: 0.619, across 568 examples.
#
#
# Annotators lobel.filipic@gmail.com and navratilova@ped.muni.cz annotated   3 documents:
# 	 Cohens kappa for Aspect          is: 0.125, across 7 examples.
# 	 Cohens kappa for Aspect2         is: 0.200, across 7 examples.
# 	 Cohens kappa for Aspect3         is: 0.276, across 7 examples.
# 	 Cohens kappa for Category        is: 0.000, across 7 examples.
# 	 Cohens kappa for Expressiveness  is: 0.160, across 7 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 7 examples.
# 	 Cohens kappa for Targetlevel     is: 0.000, across 7 examples.
# 	 Cohens kappa for Targettype      is: -0.029, across 7 examples.
#
#
# Annotators marcintrk@gmail.com and navratilova@ped.muni.cz annotated  61 documents:
# 	 Cohens kappa for Aspect          is: 0.318, across 150 examples.
# 	 Cohens kappa for Aspect2         is: 0.004, across 150 examples.
# 	 Cohens kappa for Aspect3         is: -0.007, across 150 examples.
# 	 Cohens kappa for Category        is: 0.208, across 150 examples.
# 	 Cohens kappa for Expressiveness  is: 0.624, across 150 examples.
# 	 Cohens kappa for Figurative      is: 0.525, across 150 examples.
# 	 Cohens kappa for Targetlevel     is: 0.457, across 150 examples.
# 	 Cohens kappa for Targettype      is: 0.635, across 150 examples.
#
#
# Annotators marcintrk@gmail.com and paul.wilson@uni.lodz.pl annotated  61 documents:
# 	 Cohens kappa for Aspect          is: 0.413, across 124 examples.
# 	 Cohens kappa for Aspect2         is: 0.011, across 124 examples.
# 	 Cohens kappa for Aspect3         is: 0.016, across 124 examples.
# 	 Cohens kappa for Category        is: 0.278, across 124 examples.
# 	 Cohens kappa for Expressiveness  is: 0.396, across 124 examples.
# 	 Cohens kappa for Figurative      is: 0.363, across 124 examples.
# 	 Cohens kappa for Targetlevel     is: 0.281, across 124 examples.
# 	 Cohens kappa for Targettype      is: 0.307, across 124 examples.

# %% [markdown]
# ## Inter-annotator agreement between an annotator and curator

# %%
# PARAMETERS
project_path = "Offensive+language+annotation+REAL_project_2022-03-09_0806"
# Possible statuses: {'CURATION_IN_PROGRESS', 'NEW', 'ANNOTATION_IN_PROGRESS', 'CURATION_FINISHED', 'ANNOTATION_FINISHED'}
status_types = ['CURATION_FINISHED']

documents = get_documents(project_path)
document_names = select_document_names_by_type(documents, status_types)

df_annotators = get_annotation_data_frame(document_names, project_path, folder = "annotation")
df_curator = get_annotation_data_frame(document_names, project_path, folder = "curation")
df_merged = pd.concat([df_annotators, df_curator], ignore_index=True)

# get annotator list
annotators = sorted(list(set(df_annotators["Annotator"])))

# eval each annotator to a curator
for annotator in annotators:
    annotator_documents = set(df_annotators.groupby("Annotator").filter(lambda x : pd.Series([annotator]).isin(x['Annotator']).all())["Document"])

    df = df_merged[df_merged['Annotator'].isin([annotator, "CURATION_USER.tsv"])]
    df = df[df["Document"].isin(annotator_documents)]

    print(f"\n\nAnnotator {annotator.replace('.tsv', ''):15} annotated {len(annotator_documents):3} documents:")
    for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"]: 
        cohens, examples_num = get_cohen_kappa_score(df, annotation_category, verbose = False)
        print(f"\t Cohens kappa for {annotation_category:15} is: {cohens:.3f}, across {examples_num} examples.")
# Out:
# Number of documents: 113
#
#
# Annotator agnieszka_borowiak@wp.pl annotated   2 documents:
# 	 Cohens kappa for Aspect          is: 0.118, across 15 examples.
# 	 Cohens kappa for Aspect2         is: nan, across 15 examples.
# 	 Cohens kappa for Aspect3         is: nan, across 15 examples.
# 	 Cohens kappa for Category        is: 0.217, across 15 examples.
# 	 Cohens kappa for Expressiveness  is: 0.211, across 15 examples.
# 	 Cohens kappa for Figurative      is: 0.217, across 15 examples.
# 	 Cohens kappa for Targetlevel     is: 0.132, across 15 examples.
# 	 Cohens kappa for Targettype      is: 0.132, across 15 examples.
#
#
# Annotator ana.ostroski@gmail.com annotated  34 documents:
# 	 Cohens kappa for Aspect          is: 0.681, across 399 examples.
# 	 Cohens kappa for Aspect2         is: 0.620, across 399 examples.
# 	 Cohens kappa for Aspect3         is: 0.360, across 399 examples.
# 	 Cohens kappa for Category        is: 0.705, across 399 examples.
# 	 Cohens kappa for Expressiveness  is: 0.721, across 399 examples.
# 	 Cohens kappa for Figurative      is: 0.657, across 399 examples.
# 	 Cohens kappa for Targetlevel     is: 0.709, across 399 examples.
# 	 Cohens kappa for Targettype      is: 0.725, across 399 examples.
#
#
# Annotator annab           annotated   1 documents:
# 	 Cohens kappa for Aspect          is: 0.000, across 5 examples.
# 	 Cohens kappa for Aspect2         is: 0.000, across 5 examples.
# 	 Cohens kappa for Aspect3         is: 0.000, across 5 examples.
# 	 Cohens kappa for Category        is: 0.000, across 5 examples.
# 	 Cohens kappa for Expressiveness  is: 0.000, across 5 examples.
# 	 Cohens kappa for Figurative      is: 0.000, across 5 examples.
# 	 Cohens kappa for Targetlevel     is: 0.000, across 5 examples.
# 	 Cohens kappa for Targettype      is: 0.000, across 5 examples.
#
#
# Annotator barbaral        annotated  14 documents:
# 	 Cohens kappa for Aspect          is: 0.462, across 50 examples.
# 	 Cohens kappa for Aspect2         is: 0.489, across 50 examples.
# 	 Cohens kappa for Aspect3         is: 0.525, across 50 examples.
# 	 Cohens kappa for Category        is: 0.460, across 50 examples.
# 	 Cohens kappa for Expressiveness  is: 0.460, across 50 examples.
# 	 Cohens kappa for Figurative      is: 0.474, across 50 examples.
# 	 Cohens kappa for Targetlevel     is: 0.446, across 50 examples.
# 	 Cohens kappa for Targettype      is: 0.481, across 50 examples.
#
#
# Annotator ibrac@ihjj.hr   annotated  65 documents:
# 	 Cohens kappa for Aspect          is: 0.644, across 492 examples.
# 	 Cohens kappa for Aspect2         is: 0.507, across 492 examples.
# 	 Cohens kappa for Aspect3         is: 0.574, across 492 examples.
# 	 Cohens kappa for Category        is: 0.597, across 492 examples.
# 	 Cohens kappa for Expressiveness  is: 0.676, across 492 examples.
# 	 Cohens kappa for Figurative      is: 0.484, across 492 examples.
# 	 Cohens kappa for Targetlevel     is: 0.673, across 492 examples.
# 	 Cohens kappa for Targettype      is: 0.680, across 492 examples.
#
#
# Annotator jecovit@gmail.com annotated  22 documents:
# 	 Cohens kappa for Aspect          is: 0.366, across 102 examples.
# 	 Cohens kappa for Aspect2         is: 0.417, across 102 examples.
# 	 Cohens kappa for Aspect3         is: 0.000, across 102 examples.
# 	 Cohens kappa for Category        is: 0.249, across 102 examples.
# 	 Cohens kappa for Expressiveness  is: 0.456, across 102 examples.
# 	 Cohens kappa for Figurative      is: 0.406, across 102 examples.
# 	 Cohens kappa for Targetlevel     is: 0.327, across 102 examples.
# 	 Cohens kappa for Targettype      is: 0.439, across 102 examples.
#
#
# Annotator kristina.despot@gmail.com annotated  48 documents:
# 	 Cohens kappa for Aspect          is: 0.662, across 563 examples.
# 	 Cohens kappa for Aspect2         is: 0.617, across 563 examples.
# 	 Cohens kappa for Aspect3         is: 0.873, across 563 examples.
# 	 Cohens kappa for Category        is: 0.621, across 563 examples.
# 	 Cohens kappa for Expressiveness  is: 0.653, across 563 examples.
# 	 Cohens kappa for Figurative      is: 0.597, across 563 examples.
# 	 Cohens kappa for Targetlevel     is: 0.621, across 563 examples.
# 	 Cohens kappa for Targettype      is: 0.643, across 563 examples.
#
#
# Annotator lobel.filipic@gmail.com annotated  34 documents:
# 	 Cohens kappa for Aspect          is: 0.678, across 280 examples.
# 	 Cohens kappa for Aspect2         is: 0.528, across 280 examples.
# 	 Cohens kappa for Aspect3         is: 0.299, across 280 examples.
# 	 Cohens kappa for Category        is: 0.583, across 280 examples.
# 	 Cohens kappa for Expressiveness  is: 0.708, across 280 examples.
# 	 Cohens kappa for Figurative      is: 0.608, across 280 examples.
# 	 Cohens kappa for Targetlevel     is: 0.684, across 280 examples.
# 	 Cohens kappa for Targettype      is: 0.672, across 280 examples.
#
#
# Annotator navratilova@ped.muni.cz annotated  21 documents:
# 	 Cohens kappa for Aspect          is: 0.534, across 291 examples.
# 	 Cohens kappa for Aspect2         is: 0.539, across 291 examples.
# 	 Cohens kappa for Aspect3         is: 0.666, across 291 examples.
# 	 Cohens kappa for Category        is: 0.552, across 291 examples.
# 	 Cohens kappa for Expressiveness  is: 0.560, across 291 examples.
# 	 Cohens kappa for Figurative      is: 0.566, across 291 examples.
# 	 Cohens kappa for Targetlevel     is: 0.549, across 291 examples.
# 	 Cohens kappa for Targettype      is: 0.569, across 291 examples.

# %% [markdown]
# Discussion questions:
#
# * Multiple labelings of the same sentence - how to take them into account?
# * Curator's feeling aligned with the results above?
# * Check if there are documents that can be removed to get better results?
#   * Not much data available to really have representative value - only 500 documents annotated and only 113 curated (March 10, 2022)?
