# %% [markdown]
# # Offensive language annotation campaign analysis
#
# * sklearn Cohen kappa: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.cohen_kappa_score.html#sklearn.metrics.cohen_kappa_score
# * kappa's comparison: https://towardsdatascience.com/inter-rater-agreement-kappas-69cd8b91ff75
#
# Cohen's Kappa interpretation:
# ![](kappa-interpretation.png)
#
# # Script - imports and functions

# %%
# IMPORTS
import json
import glob
import re
import pandas as pd
from sklearn import metrics as sk_metrics

import warnings
warnings.filterwarnings("ignore")

PROJECT_PATH = "Offensive+language+annotation+REAL_project_2022-05-17_0837"
PROJECT_JSON = "exportedproject34691943939792533.json"

SKIP_ANNOTATORS = ["admin.tsv", "annab.tsv", "barbaral.tsv", "jecovit@gmail.com.tsv"]

# %%
def get_documents(project_path):
    # Get possible statuses from project JSON
    project_json_file = project_path + "/" + PROJECT_JSON
    project_data = json.load(open(project_json_file))

    document_statuses = set()
    documents = []
    for document in project_data["source_documents"]:
        document_statuses.add(document["state"])
        documents.append((document["name"], document["state"]))

    #print(f"Possible statuses: {document_statuses}")
    return documents

# %%
def select_document_names_by_type(documents, status_types):
    # Select documents
    document_names = [doc[0] for doc in documents if doc[1] in status_types]
    print(f"Number of documents: {len(document_names)}")
    return document_names

# %%
# Prepare annotation objects
def annotations_from_tsv_file(filename, annotation_category):
    # Second line should look as follows:
    # #T_SP=webanno.custom.Offensivelanguage|Aspect|Aspect2|Aspect3|Category|Expressiveness|Figurative|Targetlevel|Targettype
    lines = open(filename).readlines()
    
    # get annotation index
    annotation_index = 0
    tsv_header = lines[1].split("|")
    if tsv_header[0] == "#T_SP=webanno.custom.Offensivelanguage":
        annotation_index = tsv_header.index(annotation_category)-1
    else:
        # Document contains no annotations
        annotation_index = -1
        
    # get indices of new lines
    indices = [i for i, x in enumerate(lines) if x == "\n"]
    # Add last index
    indices.append(len(lines))

    # get pairs of indices to get sentences
    pair_indices = []
    for i in range(len(indices)-1):
        if abs(indices[i]-indices[i+1]) > 1: #remove duplicate new lines (beginning of document)
            pair_indices.append(indices[i:i+2])

    # get sentences
    sentences = []
    for pair in pair_indices:
        # First sentence element is always text
        sentences.append(lines[pair[0]+1:pair[1]])

    # get annotations
    annotations = []
    for sentence in sentences:
        if annotation_index == -1:
            annotations.append("None")
        else:
            annotation = sentence[1].split("\t")[3+annotation_index]
            if annotation == "_":
                annotation = "None"                        
            annotation = re.sub(r"\[.*?\]", "", annotation) # remove annotation indexes
            annotation = annotation.replace("*", "None")
            annotation = annotation.replace("|None|", "|")
            annotation = annotation.replace("None|", "")
            annotation = annotation.replace("|None", "")
            annotation = "|".join(sorted(annotation.split("|"))) # sort annotations if multiple present
            annotations.append(annotation)            
        
    return annotations

# %%
# folder can be annotation or curation
def get_annotation_data_frame(document_names, project_path, folder = "annotation"):
    # Get possible statuses from project JSON
    #project_json_file = project_path + "/" + PROJECT_JSON
    #project_data = json.load(open(project_json_file))
    #doc_and_user_to_status = dict()
    #for data in project_data["annotation_documents"]:
    #    doc_and_user_to_status[(data["name"], data["user"])] = data["annotatorState"]
    #print(f"All annotator states: {set(doc_and_user_to_status.values())}")
    
    all_annotations = []
    # get all annotations per document
    # each annotations looks like (document_name, annotator_name, [annotations])
    for document_name in document_names:
        annotator_files = glob.glob(f"{project_path}/{folder}/{document_name}/*.tsv")

        #get annotations per document
        for annotator_file in annotator_files:
            annotator = annotator_file.split("/")[-1]
            
            if annotator not in SKIP_ANNOTATORS:
            
                annotations = [document_name, annotator]
                # Possible annotation categories:
                # Aspect|Aspect2|Aspect3|Category|Expressiveness|Figurative|Targetlevel|Targettype
                for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype\n"]:
                    annotations.append(annotations_from_tsv_file(annotator_file, annotation_category))

                all_annotations.append(annotations)

    df = pd.DataFrame(all_annotations, columns =['Document', 'Annotator', "Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"])
    return df

# %%
def get_annotator_groups_per_document(df, verbose = True):
    groups = set()
    for group in df.groupby("Document")["Annotator"].apply(list):
        groups.add(tuple(sorted(group)))
    if verbose:
        print(f"\nGroups: \n\t{groups}\n")
    return groups

# %%
def get_cohen_kappa_score(df, annotation_category, verbose = True):

    # get all annotation labels
    annotation_labels = set()
    for annotation_data in list(df[annotation_category]):
        annotation_labels.update(annotation_data)

    if verbose:
        print(f"All read different annotation labels: \n\t{annotation_labels}\n")
    
    # get annotator groups per document
    groups= get_annotator_groups_per_document(df, verbose)

    #for row in df.groupby("Document")["Annotator"]:
    #    print(list(row[1]))
    
    # get annotation pair lists
    annotations_one = []
    annotations_two = []
    for annotations_pair in df.groupby("Document")[annotation_category].apply(list):
        if len(annotations_pair) != 2:
            raise Exception(f"More than two annotators per document: '{annotations_pair}'!")

        annotations_one.extend(annotations_pair[0])
        annotations_two.extend(annotations_pair[1])

    # both lists should be of same length
    assert len(annotations_one) == len(annotations_two)
    if verbose:
        print(f"We are comparing {len(annotations_one)} annotated sentences.")
    
    # change label values (None, 0, 1, 2, 3, ...)
    label_mapping = {"None": -1}
    cur_mapping_id = 0
    for label in annotation_labels:
        if label != "None" and label not in label_mapping:
            label_mapping[label] = cur_mapping_id
            cur_mapping_id += 1
    if verbose:
        print(f"Mapping table: {label_mapping}")
    
    # calculate IAA
    annotations_iaa_a = list(map(lambda x: label_mapping[x] if x!="None" else -1, annotations_one)) 
    annotations_iaa_b = list(map(lambda x: label_mapping[x] if x!="None" else -1, annotations_two))
    cohens = sk_metrics.cohen_kappa_score(annotations_iaa_a, annotations_iaa_b)
    return cohens, len(annotations_one)

# %%
def aspects_match(df):
    matches_count = dict()
    matches_count[0] = 0
    matches_count[1] = 0
    matches_count[2] = 0
    matches_count[3] = 0
    
    aspects1 = df.groupby("Document")["Aspect"].apply(list)
    aspects2 = df.groupby("Document")["Aspect2"].apply(list)
    aspects3 = df.groupby("Document")["Aspect3"].apply(list)
    
    for aspects_annotation in aspects1:
        if len(aspects_annotation) != 2:
                raise Exception(f"More than two annotators per document:\n\t{list(aspects_annotation)}")
        
    for aspects_annotation in aspects2:
        if len(aspects_annotation) != 2:
                raise Exception(f"More than two annotators per document:\n\t{list(aspects_annotation)}")
    
    for aspects_annotation in aspects3:
        if len(aspects_annotation) != 2:
                raise Exception(f"More than two annotators per document:\n\t{list(aspects_annotation)}")
            
    for zipped_docs in zip(aspects1, aspects2, aspects3):
        # here will be list of aspects - each object are three-tuple = three aspects 
        annotator_one_aspects = []
        annotator_two_aspects = []
        
        #(aspects1 list, aspects2 list, aspects3 list)
        #annotator a
        for annotations in zip(zipped_docs[0][0], zipped_docs[1][0], zipped_docs[2][0]):
            aspects_set = {annotations[0], annotations[1], annotations[2]}
            aspects_set.discard('None')
            annotator_one_aspects.append(aspects_set)
        #annotator b
        for annotations in zip(zipped_docs[0][1], zipped_docs[1][1], zipped_docs[2][1]):
            aspects_set = {annotations[0], annotations[1], annotations[2]}
            aspects_set.discard('None')
            annotator_two_aspects.append(aspects_set)
            
        
        for aspects in zip(annotator_one_aspects, annotator_two_aspects):
            if len(aspects[0]) != 0 and len(aspects[1]) != 0: #otherwise no one annotated a sentence, take into account of one of the annotators annotated
                
                # take multi-label into account! 
                aspects_a = set()
                aspects_b = set()
                for m_aspect in aspects[0]:                    
                    for a in m_aspect.split("|"):
                        aspects_a.add(a)
                for m_aspect in aspects[1]:                    
                    for a in m_aspect.split("|"):
                        aspects_b.add(a)
                
                match_size = len(aspects_a.intersection(aspects_b))
                matches_count[match_size] = matches_count[match_size] + 1

    return matches_count

# %% [markdown]
# # Analysis by type
#
# ## Inter-annotator agreement between annotators (in general)

# %%
# PARAMETERS
project_path = PROJECT_PATH
# Possible statuses: {'CURATION_IN_PROGRESS', 'NEW', 'ANNOTATION_IN_PROGRESS', 'CURATION_FINISHED', 'ANNOTATION_FINISHED'}
status_types = ['ANNOTATION_FINISHED']

documents = get_documents(project_path)
document_names = select_document_names_by_type(documents, status_types)
df = get_annotation_data_frame(document_names, project_path, folder = "annotation")

#Eval
all_aspects_results = aspects_match(df)
all_aspects_results_sum = sum(all_aspects_results.values())
if all_aspects_results_sum != 0:
    print(f"All aspects match - 0: {all_aspects_results[0]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[0]} sentences.")
    print(f"All aspects match - 1: {all_aspects_results[1]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[1]} sentences.")
    print(f"All aspects match - 2: {all_aspects_results[2]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[2]} sentences.")
    print(f"All aspects match - 3: {all_aspects_results[3]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[3]} sentences.")

for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"]: 
    cohens, examples_num = get_cohen_kappa_score(df, annotation_category, verbose = False)
    print(f"Cohens kappa for {annotation_category:15} between annotator a and b: {cohens:.3f}, across {examples_num} sentences.")
# Out:
# Number of documents: 331
# All aspects match - 0: 20.6%, i.e., 62 sentences.
# All aspects match - 1: 69.4%, i.e., 209 sentences.
# All aspects match - 2: 9.6%, i.e., 29 sentences.
# All aspects match - 3: 0.3%, i.e., 1 sentences.
# Cohens kappa for Aspect          between annotator a and b: 0.291, across 1264 sentences.
# Cohens kappa for Aspect2         between annotator a and b: 0.260, across 1264 sentences.
# Cohens kappa for Aspect3         between annotator a and b: 0.182, across 1264 sentences.
# Cohens kappa for Category        between annotator a and b: 0.322, across 1264 sentences.
# Cohens kappa for Expressiveness  between annotator a and b: 0.487, across 1264 sentences.
# Cohens kappa for Figurative      between annotator a and b: 0.188, across 1264 sentences.
# Cohens kappa for Targetlevel     between annotator a and b: 0.444, across 1264 sentences.
# Cohens kappa for Targettype      between annotator a and b: 0.432, across 1264 sentences.

# %% [markdown]
# ## Inter-annotator agreement between annotators

# %%
# PARAMETERS
project_path = PROJECT_PATH
# Possible statuses: {'CURATION_IN_PROGRESS', 'NEW', 'ANNOTATION_IN_PROGRESS', 'CURATION_FINISHED', 'ANNOTATION_FINISHED'}
status_types = ['ANNOTATION_FINISHED']

documents = get_documents(project_path)
document_names = select_document_names_by_type(documents, status_types)

df_annotators = get_annotation_data_frame(document_names, project_path, folder = "annotation")

# get annotator pairs (groups)
groups = sorted(list(get_annotator_groups_per_document(df_annotators, verbose = False)))

for pair in groups:
    if len(pair) != 2:
        raise Exception(f"More than two annotators per document: '{annotations_pair}'!")
        
    annotator1 = pair[0]
    annotator2 = pair[1]
    
    annotator1_documents = set(df_annotators.groupby("Annotator").filter(lambda x : pd.Series([annotator1]).isin(x['Annotator']).all())["Document"])
    annotator2_documents = set(df_annotators.groupby("Annotator").filter(lambda x : pd.Series([annotator2]).isin(x['Annotator']).all())["Document"])
    annotator_documents = annotator1_documents.intersection(annotator2_documents) 
    
    df = df_annotators[df_annotators['Annotator'].isin([annotator1, annotator2])]
    df = df[df["Document"].isin(annotator_documents)]
    
    print(f"\n\nAnnotators {annotator1.replace('.tsv', ''):15} and {annotator2.replace('.tsv', ''):15} annotated {len(annotator_documents):3} documents:")
    
    all_aspects_results = aspects_match(df)
    all_aspects_results_sum = sum(all_aspects_results.values())
    if all_aspects_results_sum != 0:
        print(f"\t All aspects match - 0: {all_aspects_results[0]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[0]} sentences.")
        print(f"\t All aspects match - 1: {all_aspects_results[1]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[1]} sentences.")
        print(f"\t All aspects match - 2: {all_aspects_results[2]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[2]} sentences.")
        print(f"\t All aspects match - 3: {all_aspects_results[3]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[3]} sentences.")

    for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"]: 
        cohens, examples_num = get_cohen_kappa_score(df, annotation_category, verbose = False)
        print(f"\t Cohens kappa for {annotation_category:15} is: {cohens:.3f}, across {examples_num} sentences.")
# Out:
# Number of documents: 331
#
#
# Annotators agnieszka_borowiak@wp.pl and ana.ostroski@gmail.com annotated   9 documents:
# 	 All aspects match - 0: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 1: 100.0%, i.e., 6 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.510, across 57 sentences.
# 	 Cohens kappa for Aspect2         is: 0.000, across 57 sentences.
# 	 Cohens kappa for Aspect3         is: 0.000, across 57 sentences.
# 	 Cohens kappa for Category        is: 0.242, across 57 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.341, across 57 sentences.
# 	 Cohens kappa for Figurative      is: 0.139, across 57 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.574, across 57 sentences.
# 	 Cohens kappa for Targettype      is: 0.568, across 57 sentences.
#
#
# Annotators agnieszka_borowiak@wp.pl and lobel.filipic@gmail.com annotated   1 documents:
# 	 All aspects match - 0: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 1: 100.0%, i.e., 2 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.255, across 19 sentences.
# 	 Cohens kappa for Aspect2         is: 0.000, across 19 sentences.
# 	 Cohens kappa for Aspect3         is: nan, across 19 sentences.
# 	 Cohens kappa for Category        is: 0.441, across 19 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.612, across 19 sentences.
# 	 Cohens kappa for Figurative      is: -0.036, across 19 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.283, across 19 sentences.
# 	 Cohens kappa for Targettype      is: 0.452, across 19 sentences.
#
#
# Annotators agnieszka_borowiak@wp.pl and marcintrk@gmail.com annotated  74 documents:
# 	 All aspects match - 0: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 1: 100.0%, i.e., 11 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.217, across 210 sentences.
# 	 Cohens kappa for Aspect2         is: 0.116, across 210 sentences.
# 	 Cohens kappa for Aspect3         is: 0.000, across 210 sentences.
# 	 Cohens kappa for Category        is: 0.165, across 210 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.264, across 210 sentences.
# 	 Cohens kappa for Figurative      is: 0.246, across 210 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.216, across 210 sentences.
# 	 Cohens kappa for Targettype      is: 0.231, across 210 sentences.
#
#
# Annotators agnieszka_borowiak@wp.pl and navratilova@ped.muni.cz annotated  42 documents:
# 	 All aspects match - 0: 71.7%, i.e., 33 sentences.
# 	 All aspects match - 1: 28.3%, i.e., 13 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.132, across 101 sentences.
# 	 Cohens kappa for Aspect2         is: 0.070, across 101 sentences.
# 	 Cohens kappa for Aspect3         is: nan, across 101 sentences.
# 	 Cohens kappa for Category        is: 0.090, across 101 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.344, across 101 sentences.
# 	 Cohens kappa for Figurative      is: 0.297, across 101 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.182, across 101 sentences.
# 	 Cohens kappa for Targettype      is: 0.114, across 101 sentences.
#
#
# Annotators agnieszka_borowiak@wp.pl and paul.wilson@uni.lodz.pl annotated  68 documents:
# 	 All aspects match - 0: 14.8%, i.e., 8 sentences.
# 	 All aspects match - 1: 66.7%, i.e., 36 sentences.
# 	 All aspects match - 2: 18.5%, i.e., 10 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.229, across 168 sentences.
# 	 Cohens kappa for Aspect2         is: 0.214, across 168 sentences.
# 	 Cohens kappa for Aspect3         is: 0.141, across 168 sentences.
# 	 Cohens kappa for Category        is: 0.142, across 168 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.311, across 168 sentences.
# 	 Cohens kappa for Figurative      is: 0.327, across 168 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.277, across 168 sentences.
# 	 Cohens kappa for Targettype      is: 0.263, across 168 sentences.
#
#
# Annotators ana.ostroski@gmail.com and ibrac@ihjj.hr   annotated   6 documents:
# 	 All aspects match - 0: 16.7%, i.e., 1 sentences.
# 	 All aspects match - 1: 83.3%, i.e., 5 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.354, across 47 sentences.
# 	 Cohens kappa for Aspect2         is: 0.174, across 47 sentences.
# 	 Cohens kappa for Aspect3         is: 0.000, across 47 sentences.
# 	 Cohens kappa for Category        is: 0.258, across 47 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.509, across 47 sentences.
# 	 Cohens kappa for Figurative      is: nan, across 47 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.527, across 47 sentences.
# 	 Cohens kappa for Targettype      is: 0.525, across 47 sentences.
#
#
# Annotators ana.ostroski@gmail.com and lobel.filipic@gmail.com annotated   6 documents:
# 	 All aspects match - 0: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 1: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 2: 100.0%, i.e., 1 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.313, across 23 sentences.
# 	 Cohens kappa for Aspect2         is: 0.313, across 23 sentences.
# 	 Cohens kappa for Aspect3         is: nan, across 23 sentences.
# 	 Cohens kappa for Category        is: 0.652, across 23 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.646, across 23 sentences.
# 	 Cohens kappa for Figurative      is: nan, across 23 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.646, across 23 sentences.
# 	 Cohens kappa for Targettype      is: 0.652, across 23 sentences.
#
#
# Annotators ana.ostroski@gmail.com and marcintrk@gmail.com annotated   1 documents:
# 	 Cohens kappa for Aspect          is: 0.000, across 10 sentences.
# 	 Cohens kappa for Aspect2         is: 0.000, across 10 sentences.
# 	 Cohens kappa for Aspect3         is: nan, across 10 sentences.
# 	 Cohens kappa for Category        is: 0.000, across 10 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.000, across 10 sentences.
# 	 Cohens kappa for Figurative      is: 0.000, across 10 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.000, across 10 sentences.
# 	 Cohens kappa for Targettype      is: 0.000, across 10 sentences.
#
#
# Annotators ana.ostroski@gmail.com and navratilova@ped.muni.cz annotated   6 documents:
# 	 All aspects match - 0: 33.3%, i.e., 1 sentences.
# 	 All aspects match - 1: 33.3%, i.e., 1 sentences.
# 	 All aspects match - 2: 33.3%, i.e., 1 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.230, across 22 sentences.
# 	 Cohens kappa for Aspect2         is: 0.224, across 22 sentences.
# 	 Cohens kappa for Aspect3         is: nan, across 22 sentences.
# 	 Cohens kappa for Category        is: 0.252, across 22 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.430, across 22 sentences.
# 	 Cohens kappa for Figurative      is: 0.000, across 22 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.409, across 22 sentences.
# 	 Cohens kappa for Targettype      is: 0.450, across 22 sentences.
#
#
# Annotators ana.ostroski@gmail.com and paul.wilson@uni.lodz.pl annotated  11 documents:
# 	 All aspects match - 0: 22.2%, i.e., 2 sentences.
# 	 All aspects match - 1: 66.7%, i.e., 6 sentences.
# 	 All aspects match - 2: 11.1%, i.e., 1 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.334, across 25 sentences.
# 	 Cohens kappa for Aspect2         is: 0.257, across 25 sentences.
# 	 Cohens kappa for Aspect3         is: 0.227, across 25 sentences.
# 	 Cohens kappa for Category        is: 0.224, across 25 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.286, across 25 sentences.
# 	 Cohens kappa for Figurative      is: 0.008, across 25 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.390, across 25 sentences.
# 	 Cohens kappa for Targettype      is: 0.358, across 25 sentences.
#
#
# Annotators ibrac@ihjj.hr   and lobel.filipic@gmail.com annotated   6 documents:
# 	 All aspects match - 0: 33.3%, i.e., 1 sentences.
# 	 All aspects match - 1: 33.3%, i.e., 1 sentences.
# 	 All aspects match - 2: 33.3%, i.e., 1 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.253, across 47 sentences.
# 	 Cohens kappa for Aspect2         is: 0.116, across 47 sentences.
# 	 Cohens kappa for Aspect3         is: 0.000, across 47 sentences.
# 	 Cohens kappa for Category        is: 0.155, across 47 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.396, across 47 sentences.
# 	 Cohens kappa for Figurative      is: 0.000, across 47 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.313, across 47 sentences.
# 	 Cohens kappa for Targettype      is: 0.384, across 47 sentences.
#
#
# Annotators ibrac@ihjj.hr   and marcintrk@gmail.com annotated   1 documents:
# 	 All aspects match - 0: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 1: 100.0%, i.e., 1 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.338, across 17 sentences.
# 	 Cohens kappa for Aspect2         is: 0.000, across 17 sentences.
# 	 Cohens kappa for Aspect3         is: nan, across 17 sentences.
# 	 Cohens kappa for Category        is: 0.160, across 17 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.346, across 17 sentences.
# 	 Cohens kappa for Figurative      is: 0.000, across 17 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.346, across 17 sentences.
# 	 Cohens kappa for Targettype      is: 0.338, across 17 sentences.
#
#
# Annotators ibrac@ihjj.hr   and navratilova@ped.muni.cz annotated  20 documents:
# 	 All aspects match - 0: 20.8%, i.e., 5 sentences.
# 	 All aspects match - 1: 79.2%, i.e., 19 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.192, across 98 sentences.
# 	 Cohens kappa for Aspect2         is: 0.093, across 98 sentences.
# 	 Cohens kappa for Aspect3         is: 0.000, across 98 sentences.
# 	 Cohens kappa for Category        is: 0.175, across 98 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.319, across 98 sentences.
# 	 Cohens kappa for Figurative      is: 0.000, across 98 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.350, across 98 sentences.
# 	 Cohens kappa for Targettype      is: 0.336, across 98 sentences.
#
#
# Annotators ibrac@ihjj.hr   and paul.wilson@uni.lodz.pl annotated   1 documents:
# 	 All aspects match - 0: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 1: 100.0%, i.e., 6 sentences.
# 	 All aspects match - 2: 0.0%, i.e., 0 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.062, across 10 sentences.
# 	 Cohens kappa for Aspect2         is: 0.194, across 10 sentences.
# 	 Cohens kappa for Aspect3         is: 0.000, across 10 sentences.
# 	 Cohens kappa for Category        is: 0.043, across 10 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.038, across 10 sentences.
# 	 Cohens kappa for Figurative      is: 0.000, across 10 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.211, across 10 sentences.
# 	 Cohens kappa for Targettype      is: 0.538, across 10 sentences.
#
#
# Annotators lobel.filipic@gmail.com and marcintrk@gmail.com annotated  74 documents:
# 	 All aspects match - 0: 8.0%, i.e., 10 sentences.
# 	 All aspects match - 1: 80.0%, i.e., 100 sentences.
# 	 All aspects match - 2: 11.2%, i.e., 14 sentences.
# 	 All aspects match - 3: 0.8%, i.e., 1 sentences.
# 	 Cohens kappa for Aspect          is: 0.315, across 394 sentences.
# 	 Cohens kappa for Aspect2         is: 0.310, across 394 sentences.
# 	 Cohens kappa for Aspect3         is: 0.208, across 394 sentences.
# 	 Cohens kappa for Category        is: 0.551, across 394 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.654, across 394 sentences.
# 	 Cohens kappa for Figurative      is: 0.031, across 394 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.628, across 394 sentences.
# 	 Cohens kappa for Targettype      is: 0.601, across 394 sentences.
#
#
# Annotators lobel.filipic@gmail.com and navratilova@ped.muni.cz annotated   5 documents:
# 	 All aspects match - 0: 25.0%, i.e., 1 sentences.
# 	 All aspects match - 1: 50.0%, i.e., 2 sentences.
# 	 All aspects match - 2: 25.0%, i.e., 1 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.215, across 16 sentences.
# 	 Cohens kappa for Aspect2         is: 0.347, across 16 sentences.
# 	 Cohens kappa for Aspect3         is: 0.351, across 16 sentences.
# 	 Cohens kappa for Category        is: 0.135, across 16 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.324, across 16 sentences.
# 	 Cohens kappa for Figurative      is: 0.000, across 16 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.105, across 16 sentences.
# 	 Cohens kappa for Targettype      is: 0.147, across 16 sentences.

# %% [markdown]
# ## Inter-annotator agreement between an annotator and curator

# %%
# PARAMETERS
project_path = PROJECT_PATH
# Possible statuses: {'CURATION_IN_PROGRESS', 'NEW', 'ANNOTATION_IN_PROGRESS', 'CURATION_FINISHED', 'ANNOTATION_FINISHED'}
status_types = ['CURATION_FINISHED']

documents = get_documents(project_path)
document_names = select_document_names_by_type(documents, status_types)

df_annotators = get_annotation_data_frame(document_names, project_path, folder = "annotation")
df_curator = get_annotation_data_frame(document_names, project_path, folder = "curation")
df_merged = pd.concat([df_annotators, df_curator], ignore_index=True)

# get annotator list
annotators = sorted(list(set(df_annotators["Annotator"])))

# eval each annotator to a curator
for annotator in annotators:
    annotator_documents = set(df_annotators.groupby("Annotator").filter(lambda x : pd.Series([annotator]).isin(x['Annotator']).all())["Document"])

    df = df_merged[df_merged['Annotator'].isin([annotator, "CURATION_USER.tsv"])]
    df = df[df["Document"].isin(annotator_documents)]

    print(f"\n\nAnnotator {annotator.replace('.tsv', ''):15} annotated {len(annotator_documents):3} documents:")
    
    all_aspects_results = aspects_match(df)
    all_aspects_results_sum = sum(all_aspects_results.values())
    if all_aspects_results_sum != 0:
        print(f"\t All aspects match - 0: {all_aspects_results[0]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[0]} sentences.")
        print(f"\t All aspects match - 1: {all_aspects_results[1]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[1]} sentences.")
        print(f"\t All aspects match - 2: {all_aspects_results[2]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[2]} sentences.")
        print(f"\t All aspects match - 3: {all_aspects_results[3]/all_aspects_results_sum*100:2.1f}%, i.e., {all_aspects_results[3]} sentences.")
    
    for annotation_category in ["Aspect","Aspect2","Aspect3","Category","Expressiveness","Figurative","Targetlevel","Targettype"]: 
        cohens, examples_num = get_cohen_kappa_score(df, annotation_category, verbose = False)
        print(f"\t Cohens kappa for {annotation_category:15} is: {cohens:.3f}, across {examples_num} sentences.")
# Out:
# Number of documents: 519
#
#
# Annotator agnieszka_borowiak@wp.pl annotated  33 documents:
# 	 All aspects match - 0: 14.7%, i.e., 10 sentences.
# 	 All aspects match - 1: 82.4%, i.e., 56 sentences.
# 	 All aspects match - 2: 2.9%, i.e., 2 sentences.
# 	 All aspects match - 3: 0.0%, i.e., 0 sentences.
# 	 Cohens kappa for Aspect          is: 0.732, across 276 sentences.
# 	 Cohens kappa for Aspect2         is: 0.355, across 276 sentences.
# 	 Cohens kappa for Aspect3         is: 0.197, across 276 sentences.
# 	 Cohens kappa for Category        is: 0.650, across 276 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.814, across 276 sentences.
# 	 Cohens kappa for Figurative      is: 0.679, across 276 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.790, across 276 sentences.
# 	 Cohens kappa for Targettype      is: 0.789, across 276 sentences.
#
#
# Annotator ana.ostroski@gmail.com annotated  98 documents:
# 	 All aspects match - 0: 0.8%, i.e., 1 sentences.
# 	 All aspects match - 1: 70.0%, i.e., 91 sentences.
# 	 All aspects match - 2: 26.9%, i.e., 35 sentences.
# 	 All aspects match - 3: 2.3%, i.e., 3 sentences.
# 	 Cohens kappa for Aspect          is: 0.769, across 653 sentences.
# 	 Cohens kappa for Aspect2         is: 0.683, across 653 sentences.
# 	 Cohens kappa for Aspect3         is: 0.467, across 653 sentences.
# 	 Cohens kappa for Category        is: 0.758, across 653 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.796, across 653 sentences.
# 	 Cohens kappa for Figurative      is: 0.679, across 653 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.778, across 653 sentences.
# 	 Cohens kappa for Targettype      is: 0.793, across 653 sentences.
#
#
# Annotator ibrac@ihjj.hr   annotated 294 documents:
# 	 All aspects match - 0: 7.0%, i.e., 27 sentences.
# 	 All aspects match - 1: 58.2%, i.e., 223 sentences.
# 	 All aspects match - 2: 26.4%, i.e., 101 sentences.
# 	 All aspects match - 3: 8.4%, i.e., 32 sentences.
# 	 Cohens kappa for Aspect          is: 0.682, across 1691 sentences.
# 	 Cohens kappa for Aspect2         is: 0.556, across 1691 sentences.
# 	 Cohens kappa for Aspect3         is: 0.467, across 1691 sentences.
# 	 Cohens kappa for Category        is: 0.641, across 1691 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.761, across 1691 sentences.
# 	 Cohens kappa for Figurative      is: 0.198, across 1691 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.740, across 1691 sentences.
# 	 Cohens kappa for Targettype      is: 0.771, across 1691 sentences.
#
#
# Annotator kristina.despot@gmail.com annotated  56 documents:
# 	 All aspects match - 0: 9.9%, i.e., 7 sentences.
# 	 All aspects match - 1: 66.2%, i.e., 47 sentences.
# 	 All aspects match - 2: 12.7%, i.e., 9 sentences.
# 	 All aspects match - 3: 11.3%, i.e., 8 sentences.
# 	 Cohens kappa for Aspect          is: 0.608, across 643 sentences.
# 	 Cohens kappa for Aspect2         is: 0.532, across 643 sentences.
# 	 Cohens kappa for Aspect3         is: 0.716, across 643 sentences.
# 	 Cohens kappa for Category        is: 0.598, across 643 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.630, across 643 sentences.
# 	 Cohens kappa for Figurative      is: 0.557, across 643 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.593, across 643 sentences.
# 	 Cohens kappa for Targettype      is: 0.607, across 643 sentences.
#
#
# Annotator lobel.filipic@gmail.com annotated 112 documents:
# 	 All aspects match - 0: 6.7%, i.e., 10 sentences.
# 	 All aspects match - 1: 49.7%, i.e., 74 sentences.
# 	 All aspects match - 2: 28.2%, i.e., 42 sentences.
# 	 All aspects match - 3: 15.4%, i.e., 23 sentences.
# 	 Cohens kappa for Aspect          is: 0.654, across 738 sentences.
# 	 Cohens kappa for Aspect2         is: 0.557, across 738 sentences.
# 	 Cohens kappa for Aspect3         is: 0.429, across 738 sentences.
# 	 Cohens kappa for Category        is: 0.636, across 738 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.782, across 738 sentences.
# 	 Cohens kappa for Figurative      is: 0.380, across 738 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.760, across 738 sentences.
# 	 Cohens kappa for Targettype      is: 0.763, across 738 sentences.
#
#
# Annotator marcintrk@gmail.com annotated 270 documents:
# 	 All aspects match - 0: 10.5%, i.e., 38 sentences.
# 	 All aspects match - 1: 44.4%, i.e., 161 sentences.
# 	 All aspects match - 2: 24.0%, i.e., 87 sentences.
# 	 All aspects match - 3: 21.2%, i.e., 77 sentences.
# 	 Cohens kappa for Aspect          is: 0.739, across 1066 sentences.
# 	 Cohens kappa for Aspect2         is: 0.626, across 1066 sentences.
# 	 Cohens kappa for Aspect3         is: 0.553, across 1066 sentences.
# 	 Cohens kappa for Category        is: 0.710, across 1066 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.819, across 1066 sentences.
# 	 Cohens kappa for Figurative      is: 0.658, across 1066 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.788, across 1066 sentences.
# 	 Cohens kappa for Targettype      is: 0.793, across 1066 sentences.
#
#
# Annotator navratilova@ped.muni.cz annotated  85 documents:
# 	 All aspects match - 0: 14.3%, i.e., 15 sentences.
# 	 All aspects match - 1: 77.1%, i.e., 81 sentences.
# 	 All aspects match - 2: 7.6%, i.e., 8 sentences.
# 	 All aspects match - 3: 1.0%, i.e., 1 sentences.
# 	 Cohens kappa for Aspect          is: 0.686, across 469 sentences.
# 	 Cohens kappa for Aspect2         is: 0.404, across 469 sentences.
# 	 Cohens kappa for Aspect3         is: 0.665, across 469 sentences.
# 	 Cohens kappa for Category        is: 0.626, across 469 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.767, across 469 sentences.
# 	 Cohens kappa for Figurative      is: 0.732, across 469 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.658, across 469 sentences.
# 	 Cohens kappa for Targettype      is: 0.756, across 469 sentences.
#
#
# Annotator paul.wilson@uni.lodz.pl annotated  68 documents:
# 	 All aspects match - 0: 15.1%, i.e., 13 sentences.
# 	 All aspects match - 1: 37.2%, i.e., 32 sentences.
# 	 All aspects match - 2: 24.4%, i.e., 21 sentences.
# 	 All aspects match - 3: 23.3%, i.e., 20 sentences.
# 	 Cohens kappa for Aspect          is: 0.448, across 220 sentences.
# 	 Cohens kappa for Aspect2         is: 0.523, across 220 sentences.
# 	 Cohens kappa for Aspect3         is: 0.570, across 220 sentences.
# 	 Cohens kappa for Category        is: 0.373, across 220 sentences.
# 	 Cohens kappa for Expressiveness  is: 0.502, across 220 sentences.
# 	 Cohens kappa for Figurative      is: 0.406, across 220 sentences.
# 	 Cohens kappa for Targetlevel     is: 0.428, across 220 sentences.
# 	 Cohens kappa for Targettype      is: 0.444, across 220 sentences.

# %% [markdown]
# Discussion questions:
#
# * Multiple labelings of the same sentence - how to take them into account?
# * Curator's feeling aligned with the results above?
# * Check if there are documents that can be removed to get better results?
#   * Not much data available to really have representative value - only 500 documents annotated and only 113 curated (March 10, 2022)?
#
# * All aspects - report on if both annotated a sentence or if at least one annotated.
