# %%
import gensim
import gensim.downloader
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
from sklearn.manifold import MDS
from sklearn.decomposition import PCA
import numpy as np
import tempfile
import imageio
import shutil
import os
from statistics import mean
import pandas as pd 
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer 
from gensim.test.utils import datapath
from gensim.models.fasttext import load_facebook_vectors
from gensim.models import FastText

from IPython.display import Image
from IPython.display import display
pd.options.display.max_columns = None
import seaborn as sns
from itertools import combinations

import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
import sys
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
print(gensim.__version__)
print("You are using Python {}.{}.".format(sys.version_info.major, sys.version_info.minor))
# Out:
# 4.0.1
# You are using Python 3.6.

# %% [markdown]
# ### Constants

# %%
DATASETS_FOLDER = "/Users/slavkoz/OneDrive - Univerza v Ljubljani/Datasets/Offensive language datasets/PROCESSED_DATA/"

TOP_N = 30
KEYS = { \
    "offensive": set(), 
    "abusive": set(), 
   "cyberbullying": set(), 
   "vulgar": set(), 
   "racist": set(), 
   "homophobic": set(), 
   "profane": set(), 
   "slur": set(), 
   "harassment": set(), 
   "obscene": set(), 
   "threat": set(), 
   "discredit": set(), 
   "hateful": set(), 
    "insult": set(), 
   "hostile": set(),
   "taboo": set(),
   "toxic": set()
}
FIXED_KEYS = list(KEYS.keys())

# %%
print(FIXED_KEYS)
# Out:
# ['offensive', 'abusive', 'cyberbullying', 'vulgar', 'racist', 'homophobic', 'profane', 'slur', 'harassment', 'obscene', 'threat', 'discredit', 'hateful', 'insult', 'hostile', 'taboo', 'toxic']

# %% [markdown]
# Too similar words that will not be taken into account as neighbouring words:

# %%
lemmatizer = WordNetLemmatizer() 
ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    stem = ps.stem(key)
    KEYS[key].add(lemma)
    KEYS[key].add(stem)
    KEYS[key].add(key)
KEYS
# Out:
# {'offensive': {'offens', 'offensive'},
#  'abusive': {'abus', 'abusive'},
#  'cyberbullying': {'cyberbulli', 'cyberbullying'},
#  'vulgar': {'vulgar'},
#  'racist': {'racist'},
#  'homophobic': {'homophob', 'homophobic'},
#  'profane': {'profan', 'profane'},
#  'slur': {'slur'},
#  'harassment': {'harass', 'harassment'},
#  'obscene': {'obscen', 'obscene'},
#  'threat': {'threat'},
#  'discredit': {'discredit'},
#  'hateful': {'hate', 'hateful'},
#  'insult': {'insult'},
#  'hostile': {'hostil', 'hostile'},
#  'taboo': {'taboo'},
#  'toxic': {'toxic'}}

# %% [markdown]
# ### Functions

# %%
def same_word(similar_word, ommit_words):
    similar_word = similar_word.replace("_", " ").replace("-", " ").lower()
    
    if similar_word in ommit_words:
        print(f"{ommit_words} -- {similar_word}")
        return True
    
    for ommit_word in ommit_words:
        if ommit_word in similar_word:
            print(f"{ommit_words} -- {similar_word}")
            return True
        
    return False

# %%
def getSimilarWords(model_gn):
    embedding_clusters = []
    word_clusters = []
    for key in FIXED_KEYS:
        ommit_words = KEYS[key]
        embeddings = []
        words = []
        for similar_word, _ in model_gn.wv.most_similar(key, topn=TOP_N * 3):
            if not same_word(similar_word, ommit_words):
                words.append(similar_word)
                embeddings.append(model_gn.wv[similar_word])
                
        if len(words) < TOP_N or len(embeddings) < TOP_N:
            print("ERROR")
            
        words = words[:TOP_N]
        embeddings = embeddings[:TOP_N]
        
        embedding_clusters.append(embeddings)
        word_clusters.append(words)
        
    return (word_clusters, embedding_clusters)

# %%
def displayDF(word_clusters):
    df = pd.DataFrame(dict(zip(FIXED_KEYS, word_clusters)))  
    df.to_csv('outputs/offensiveV1.csv')
    display(df)

# %%
def plot_similar_words(title, labels, embedding_clusters, word_clusters, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=0.7, label=label)
        for i, word in enumerate(words):              
            plt.annotate(label.upper(), alpha=1.0, xy=(mean(x), mean(y)), xytext=(0, 0),
            textcoords='offset points', ha='center', va='center', size=15)
    plt.legend(loc=0)
    plt.title(title)
    plt.grid(False)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
def plotTSNE(title, word_clusters, embedding_clusters,  filename = None):
    perp = 15
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = TSNE(perplexity=perp, n_components=2, init='pca', n_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotMDS(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = MDS(n_components=2, max_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotPCA(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = PCA(n_components=2, random_state = 32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
model_gn = Word2Vec.load("outputs/w2v_50dim_model_v2")
listOfWords = ['toxic','offensive',"abusive","cyberbullying","vulgar","racist","homophobic","profane","slur","harassment","obscene","threat","discredit","hateful","insult","hostile",'taboo']
word_clusters, embedding_clusters = getSimilarWords(model_gn)
plotTSNE("Similar words - Word2Vec [t-SNE]", word_clusters, embedding_clusters, "outputs/SimilarWords - word2vec - t-SNE.png")
# Out:
# {'abusive', 'abus'} -- abused
# {'racist'} -- racists
# {'homophobic', 'homophob'} -- homophobe
# {'homophobic', 'homophob'} -- homophobia
# {'profane', 'profan'} -- profanity
# {'slur'} -- slurs
# {'harassment', 'harass'} -- harassing
# {'threat'} -- threats
# {'insult'} -- insulting
# {'hostil', 'hostile'} -- hostility

# %%
def exprtWords(word,model):
    res =  model.wv.most_similar(word, topn=30)
    return [(word,x[0],x[1]) for x in res]

# %% [markdown]
# ## Word2Vec
#
# Loading model

# %%
import re
def exportToCsv(name,dic):
    with open('{}.csv'.format(name) , 'w', encoding='utf8') as w:
        for k,x in dic.items():
             w.write('{},{}\n'.format(k,",".join(x)))

def cleanKeywords(txt):
    return re.sub("\\\\",'',txt)
#     return re.sub("[^a-zA-Z]",'',txt)

def filterCsvByKeywords(_df, keyWords, orig):
    newDf = pd.DataFrame()
    for K in keyWords:
        keyWord = cleanKeywords(K)
        #         res = _df[_df['text'].isin([keyWords])]
        res = _df[_df['text'].str.contains(" {} ".format(keyWord), na=False)]
#         res = _df.filter(like= keyWord, axis=1)
        res['relatedWord'] = keyWord

        if newDf.empty:
            newDf = res

        else:
            newDf = pd.concat([newDf,res])
    newDf.to_csv('outputs/{}_examples.csv'.format(orig))

# %% [markdown]
# Load models

# %% [markdown]
# ## build heatmap

# %%
##############################
#  Module: utils.py
#  Author: Shravan Kuchkula
#  Date: 07/19/2019
##############################

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def plot_heatmap(df_hm, xlabels, ylabels):
    """
    Given a dataframe containing similarity grid, plot the heatmap
    """
    sns.set(style="white")

    # Set up the matplotlib figure
    # (to enlarge the cells, increase the figure size)
    f, ax = plt.subplots(figsize=(18, 18))

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 20, as_cmap=True)

    # Generate a mask for the upper triangle
    mask = np.zeros_like(df_hm, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(df_hm, mask=mask, cmap=cmap, center=0.5,
            xticklabels=xlabels, yticklabels=ylabels,
            square=True, linewidths=.5, fmt='.2f',
            annot=True, annot_kws={"fontsize":14}, cbar_kws={"shrink": .5}, vmax=1)
    ax.set_xticklabels(ax.get_xticklabels(),fontsize =15)
    ax.set_yticklabels(ax.get_yticklabels(),fontsize =15)

    #     ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha='left')

#     ax.set_title("Heatmap of cosine similarity scores")
    ax.set_xlabel("")
    ax.set_ylabel("")

    return ax


def similartyHeatmapPairs(pairs,model):
    '''return ((word1,word2),simScore)'''
    return [(x,model.wv.similarity(*x)) for x in pairs]
###################
# model_gn = FastText.load("")
###################
print(len(listOfWords))
listOfWordsCombinations = list(combinations(listOfWords,2))

def buildHeatmap(listCombinations,model_gn):
    similartyHeatmapData = similartyHeatmapPairs(listCombinations,model_gn)

    listOfWordsCombinationsDict = {x:k for k,x in enumerate(listOfWords)}

    p,s = zip(*similartyHeatmapData)

    df = pd.DataFrame({'pair': p, 'similarity': s})
    df_tmp =[(listOfWordsCombinationsDict.get(k[0]),listOfWordsCombinationsDict.get(k[1]),v) for k ,v in similartyHeatmapData]
    df_hm = pd.DataFrame({'ind': range(17), 'cols': range(17), 'vals': pd.Series(np.zeros(17))})

    # convert to a matrix
    df_hm = df_hm.pivot(index='ind', columns='cols').fillna(0)
    # to get lower diagnol, swap the rows and cols.
    for row, col, similarity in df_tmp:
        df_hm.iloc[col, row] = similarity
    ids = list(listOfWordsCombinationsDict.keys())
    ax = plot_heatmap(df_hm, ids, ids)
# Out:
# 17

# %%
# use model that support model.wv.similarity(word1,word2)
buildHeatmap(listOfWordsCombinations,model_gn)

# %%
###################
model_ft = FastText.load("outputs/fastText_50dim_model_v2")
###################
buildHeatmap(listOfWordsCombinations,model_ft)

# %% [markdown]
# Getting similar words. Printed out words are neighboring words that are ommited for the analysis.

# %%
word_clusters, embedding_clusters = getSimilarWords(model_ft)
# Out:
# {'offens', 'offensive'} -- unoffensive
# {'offens', 'offensive'} -- inoffensive
# {'offens', 'offensive'} -- non offensive
# {'offens', 'offensive'} -- counteroffensive
# {'offens', 'offensive'} -- offensively
# {'offens', 'offensive'} -- offensives
# {'offens', 'offensive'} -- offensiveness
# {'abusive', 'abus'} -- ==abusive
# {'abusive', 'abus'} -- abuseive
# {'abusive', 'abus'} -- abusivenegative
# {'abusive', 'abus'} -- abusively
# {'abusive', 'abus'} -- non abusive
# {'abusive', 'abus'} -- anti abuse
# {'abusive', 'abus'} -- abuse
# {'abusive', 'abus'} -- abus
# {'abusive', 'abus'} -- abusing
# {'abusive', 'abus'} -- abuse
# {'abusive', 'abus'} -- abuser
# {'abusive', 'abus'} -- abusiveness
# {'abusive', 'abus'} -- abuso
# {'abusive', 'abus'} -- abusefilter
# {'abusive', 'abus'} -- abusus
# {'cyberbulli', 'cyberbullying'} -- cyberbulling
# {'vulgar'} -- vulgaris
# {'vulgar'} -- vulgarly
# {'vulgar'} -- vulgarian
# {'racist'} -- #racist
# {'racist'} -- \racist
# {'racist'} -- noquaer4racist
# {'racist'} -- racistt
# {'racist'} -- antiracist
# {'racist'} -- anti racist
# {'racist'} -- nonracist
# {'racist'} -- racistly
# {'racist'} -- ==racist
# {'racist'} -- raciste
# {'racist'} -- racisttwat
# {'racist'} -- notracist
# {'racist'} -- racist\
# {'racist'} -- superracist
# {'racist'} -- racist==
# {'racist'} -- \racist\
# {'racist'} -- racistinchief
# {'racist'} -- racistdems
# {'racist'} -- conspiracist
# {'racist'} -- non racist
# {'racist'} -- racistic
# {'racist'} -- racist group
# {'homophobic', 'homophob'} -- homophobics
# {'homophobic', 'homophob'} -- homophob
# {'homophobic', 'homophob'} -- homophobia
# {'homophobic', 'homophob'} -- homophobs
# {'homophobic', 'homophob'} -- homophobe
# {'homophobic', 'homophob'} -- homophobes
# {'homophobic', 'homophob'} -- jesuswasgayandnothomophobic
# {'homophobic', 'homophob'} -- homophober
# {'homophobic', 'homophob'} -- stophomophobia
# {'slur'} -- slurp
# {'slur'} -- slurpy
# {'slur'} -- slurry
# {'slur'} -- slurps
# {'slur'} -- slurpee
# {'slur'} -- slurs
# {'slur'} -- slurper
# {'slur'} -- slurs==
# {'harassment', 'harass'} -- cyberharassment
# {'harassment', 'harass'} -- harassment==
# {'harassment', 'harass'} -- anti harassment
# {'harassment', 'harass'} -- wiki harassment
# {'harassment', 'harass'} -- harassement
# {'harassment', 'harass'} -- sexualharassment
# {'harassment', 'harass'} -- harassments
# {'harassment', 'harass'} -- wp:harassment
# {'obscene', 'obscen'} -- obscenely
# {'obscene', 'obscen'} -- obscenity
# {'threat'} -- cyberthreat
# {'threat'} -- altlthreat
# {'threat'} -- threatsnewl
# {'threat'} -- threath
# {'threat'} -- triplethreat
# {'threat'} -- threat==
# {'threat'} -- threats
# {'threat'} -- threatsnewlin
# {'threat'} -- threatend
# {'threat'} -- threatning
# {'threat'} -- threathening
# {'threat'} -- threaths
# {'threat'} -- threats==
# {'threat'} -- threaten
# {'threat'} -- threatening
# {'threat'} -- threatens
# {'threat'} -- threatmeter
# {'threat'} -- threathunting
# {'threat'} -- threatned
# {'threat'} -- threating
# {'discredit'} -- discreditation
# {'discredit'} -- discredits
# {'discredit'} -- discrediting
# {'hate', 'hateful'} -- hatefull
# {'hate', 'hateful'} -- hateble
# {'hate', 'hateful'} -- hatersgonnahate
# {'hate', 'hateful'} -- hatefulness
# {'hate', 'hateful'} -- hathate
# {'insult'} -- insulte
# {'insult'} -- insulter
# {'insult'} -- insultive
# {'insult'} -- insulting=guess
# {'insult'} -- insultingly
# {'insult'} -- gandinaaliinsult
# {'insult'} -- insults
# {'hostil', 'hostile'} -- `hostile
# {'hostil', 'hostile'} -- kpop hostile
# {'hostil', 'hostile'} -- hostilely
# {'hostil', 'hostile'} -- hostileenvironment
# {'taboo'} -- taboo
# {'taboo'} -- taboos
# {'taboo'} -- cmtaboo
# {'taboo'} -- tabooatpaparazzi
# {'toxic'} -- \toxic
# {'toxic'} -- nontoxic

# %%
displayDF(word_clusters)
# Out:
#         offensive          abusive   cyberbullying       vulgar  \
# 0        abrasive        insultive  cyber-bullying       bulgar
# 1       insultive       aggressive        bullying        abgar
# 2      -defensive        aggresive    antibullying     erronous
# 3        ambigous       adulterous   anti-bullying     uglydori
# 4     inadvertant      injudicious        trolling    anaerobic
# 5      attrocious          evasive       threating       slangy
# 6      derogative        obnoxious     threatening        þegar
# 7        offesive         `hostile         allying         ogar
# 8       abhorrant      insultingly        rallying         angu
# 9       obstinant    unpretentious   wiki-bullying        angus
# 10     derogatory  anti-depressant    wikibullying     mishnaic
# 11       irritant       anti-child        dallying     nastypig
# 12   prerrogative      unobtrusive         bulying       unsexy
# 13      inklusive     unprivileged         bulling   derogatory
# 14        evasive     unresponsive    anti-smoking  unoffensive
# 15  inconspicuous         abugoush         troling         slur
# 16     inc3stuous       assaultive          abhing      aerobic
# 17       obivious          anxious     bullshiting  inoffensive
# 18     insensible        obtrusive   threathunting        oleic
# 19            ant          hostile       harassing     slangin'
# 20    unconscious     kpop-hostile      threatning     sluttish
# 21       unctuous          vicious      c0rrupting     angantyr
# 22   unresponsive        malicious       disguting      insular
# 23     unconcious        persusive        trouting       slang.
# 24    derrogatory       impervious  anti-dogpiling  anglophobic
# 25        insular       mendacious      assaulting    fatphobic
# 26   misandristic         pervious        tallying      zelalic
# 27   unpersuasive        impulsive        liefting   gelatinous
# 28   anti-semetic         obivious      corrupting    offensive
# 29      offencive      anti-sexual      disobeying      yiddish
#
#               racist      homophobic          profane       slur  \
# 0         neo-facist     judeophobic  personaltrainer        slu
# 1         misogynist      xenophobic      proselytist      služi
# 2            rascist       fatphobic            profa   sluttish
# 3             facist        biphobic            prof.     slangy
# 4        anti-facist    heterophobic          prowler       slug
# 5        supremacist     lesbophobic           prof02     slushy
# 6            fascist          phobic       proszowski      sluty
# 7         mysogynist     hinduphobic  socalsupereagle    slugish
# 8   whitesupremacist     russophobic         strasser   sluggish
# 9         misoginist     iranophobic         connolly    slučaju
# 10           racisim          racist        prof.rick    slumdog
# 11       neo-fascist      homophonic          prosser   slangin'
# 12       anti-sexist      misogynist        compagnie     sluttz
# 13      clerofascist     anti-sexist        consonant      slush
# 14      nacijonalist        misogyny            prone     slutty
# 15       antifascist   #islamophobic         promjene     vulgar
# 16       nacionalist       anti-homo       con-artist   biphobic
# 17        miosgynist         \racist          prockie     slctek
# 18         racialist        anti-gay           prolly     slusho
# 19              mist    misogynistic           profar       slut
# 20            raciss         #racist        peragente      bigot
# 21       antizionist        racistly           weiter     smugly
# 22         anti-homo     anglophobic           perler     slang.
# 23      anti-zionist     anti-racist        selfpromo       slpc
# 24        misandrist    islamophobic             pron       slum
# 25       pro-fascist       nonracist        pessimist     snugly
# 26      anti-fascist       homophony         progamer       slim
# 27        liberalist  anti-pedophile           prosim  fatphobic
# 28      anti-semitic        unsexist          prosody      völur
# 29        anti-white      antiracist          dicator      slang
#
#                    harassment           obscene                 threat  \
# 0                 harrassment          en-scene                  threa
# 1                   harasment            -scene             harassment
# 2                  harrasment      hyperdescent          terror-attack
# 3                embarassment       blasphemous  excusesforthecrimein5
# 4             personalattacks     cartilaginous            harassement
# 5                 harraasment             incie              harasment
# 6                  disruption       animeatosis                  fense
# 7                    disabuse         analagous         actiontrueshot
# 8                harrassement        evanescent         idlibgasattack
# 9                     activit            oriole           embarassment
# 10                abusiveness   hemochromatosis        blockheadedness
# 11                 incivility          iptycene              unjustice
# 12                threatening            vagene        juvenilejustice
# 13                      abuse          caracter                tactile
# 14                  threating            ravage       injusticetosaint
# 15                 threatning    heteroromantic              bullycide
# 16                harrasement  uncharacteristic         counter-attack
# 17           unresponsiveness         crematory        gazaunderattack
# 18        no_personal_attacks      masturbatory            pro-offense
# 19              vandalisation       inoffensive               -defense
# 20              embarrassment            obsene            harrassment
# 21             actiontrueshot           castile            cyberattack
# 22                behaviorist             inane          counterattack
# 23             abuserdynamics        epigrapher                activit
# 24  childabusepreventionmonth          venemous                  thret
# 25             embarrassments           orioane               warcrime
# 26              cyberbullying      massagerotic         syriagasattack
# 27                     abuser       occidentale             actionshot
# 28                threatsnewl       vayathinile            attackspeed
# 29             disruptiveness  organophosphorus              injustice
#
#          discredit        hateful        insult          hostile  \
# 0            disc-    mistrustful         insul     disengenious
# 1         discrete       tolerant        excuse   immunoreactive
# 2         dicredit        fateful        assult        aggresive
# 3         disclaim  disrespectful        unmute        felonious
# 4       promulgate       trustful  insulin-like    sanctimonious
# 5       misscredit     ungrateful      embarass     disingenious
# 6         accredit    disgraceful       intrude       aggressive
# 7            disce        disgust    excuseme99      distruptive
# 8       responible        wistful     offencive  anti-depressant
# 9        co-credit  unsympathetic     embarrass     proggressive
# 10            disc       shameful      arrogate     subconscious
# 11           disc.   ohconfucious        offend    transgressive
# 12  discretisation       ignorant        attact         unactive
# 13     discrepency     ungraceful       insulin          vicious
# 14       contredit  misterpitiful       excusez   antidepressant
# 15       ignorence       spiteful         assay        torturous
# 16      condensate      #ujealous   assholemate          leprous
# 17     instantiate      stupidist   anti-semite  abusivenegative
# 18        memogate     ungracious        impugn       assaultive
# 19        disclose     ungreatful      admonish        ingenious
# 20       propigate   justtruthful     insulator     discriminant
# 21           nmate      frightful       abusive      acrimonious
# 22     remonstrate      dishonest          vult        rapacious
# 23     consentrate      sagacious    antisemite         litigant
# 24        contract     empathetic       insular       attrocious
# 25      magistrate     stupiddope       anti-se       disastrous
# 26     responcible       stupid'd    anti-flame      confrontive
# 27     pontificate        shamful      insulate           serous
# 28       prostrate        arogant    anti-semit        laborious
# 29          defame   disgusting==         idefk     disincentive
#
#                       taboo            toxic
# 0                   cariboo      /72f77gyxic
# 1                   litebay           cystic
# 2                boxinggirl       tumultuous
# 3                 chit-chat           acidic
# 4                    dingoo    heterogeneous
# 5                      spoo          #exotic
# 6                    taekey            cetic
# 7                  chitchat        synonmous
# 8                    boohoo            mimic
# 9                tattletale         sadistic
# 10  ho;ifvcgdhndashigfodsa'              uic
# 11                 ashikita     rambunctious
# 12                stonechat         neurotic
# 13        chateaubudewinery       neurogenic
# 14                  morphoo      homogeneous
# 15                    lingo        dysphoric
# 16                     taiz        unhygenic
# 17         parkinglikeatwat            nimic
# 18        horsesofinstagram          osmotic
# 19                   bamboo     neurotypical
# 20                     taik       unhygienic
# 21                   fashoo  hyper-sensitive
# 22                litterbox          bulimic
# 23                 boothang          aerobic
# 24                 plastiki         egoistic
# 25                    tasso          tantric
# 26                    footy         quixotic
# 27                tarttelin          noxious
# 28               babysitter          vacuous
# 29                    sorel             mhic

# %%
#plotPaCMAP("Similar words - Word2Vec [t-SNE]", word_clusters, embedding_clusters, "outputs/SimilarWords - word2vec - t-SNE.png")

# %%
plotTSNE("Similar words - FastText [t-SNE]", word_clusters, embedding_clusters, "outputs/SimilarWords - fastText_50_v2 - t-SNE.png")

# %%
#plotMDS("Similar words - Word2Vec [MDS]", word_clusters, embedding_clusters, "outputs/SimilarWords - word2vec - MDS.png")

# %%
plotPCA("Similar words - Word2Vec [PCA]", word_clusters, embedding_clusters, "outputs/SimilarWords - word2vec - PCA.png")

# %% [markdown]
# ## fastText
#
# Loading model

# %%
model_gn = model_ft

# %%
print(f"Vocabulary size: {len(model_gn.vocab)}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-8a16421fcc0e> in <module>
# ----> 1 print(f"Vocabulary size: {len(model_gn.vocab)}")
#
# AttributeError: 'FastText' object has no attribute 'vocab'

# %% [markdown]
# Getting similar words. Printed out words are neighboring words that are ommited for the analysis.

# %%
word_clusters, embedding_clusters = getSimilarWords(model_gn)
# Out:
# {'offens', 'offensive'} -- unoffensive
# {'offens', 'offensive'} -- inoffensive
# {'offens', 'offensive'} -- non offensive
# {'offens', 'offensive'} -- counteroffensive
# {'offens', 'offensive'} -- offensively
# {'offens', 'offensive'} -- offensives
# {'offens', 'offensive'} -- offensiveness
# {'abusive', 'abus'} -- ==abusive
# {'abusive', 'abus'} -- abuseive
# {'abusive', 'abus'} -- abusivenegative
# {'abusive', 'abus'} -- abusively
# {'abusive', 'abus'} -- non abusive
# {'abusive', 'abus'} -- anti abuse
# {'abusive', 'abus'} -- abuse
# {'abusive', 'abus'} -- abus
# {'abusive', 'abus'} -- abusing
# {'abusive', 'abus'} -- abuse
# {'abusive', 'abus'} -- abuser
# {'abusive', 'abus'} -- abusiveness
# {'abusive', 'abus'} -- abuso
# {'abusive', 'abus'} -- abusefilter
# {'abusive', 'abus'} -- abusus
# {'cyberbulli', 'cyberbullying'} -- cyberbulling
# {'vulgar'} -- vulgaris
# {'vulgar'} -- vulgarly
# {'vulgar'} -- vulgarian
# {'racist'} -- #racist
# {'racist'} -- \racist
# {'racist'} -- noquaer4racist
# {'racist'} -- racistt
# {'racist'} -- antiracist
# {'racist'} -- anti racist
# {'racist'} -- nonracist
# {'racist'} -- racistly
# {'racist'} -- ==racist
# {'racist'} -- raciste
# {'racist'} -- racisttwat
# {'racist'} -- notracist
# {'racist'} -- racist\
# {'racist'} -- superracist
# {'racist'} -- racist==
# {'racist'} -- \racist\
# {'racist'} -- racistinchief
# {'racist'} -- racistdems
# {'racist'} -- conspiracist
# {'racist'} -- non racist
# {'racist'} -- racistic
# {'racist'} -- racist group
# {'homophobic', 'homophob'} -- homophobics
# {'homophobic', 'homophob'} -- homophob
# {'homophobic', 'homophob'} -- homophobia
# {'homophobic', 'homophob'} -- homophobs
# {'homophobic', 'homophob'} -- homophobe
# {'homophobic', 'homophob'} -- homophobes
# {'homophobic', 'homophob'} -- jesuswasgayandnothomophobic
# {'homophobic', 'homophob'} -- homophober
# {'homophobic', 'homophob'} -- stophomophobia
# {'slur'} -- slurp
# {'slur'} -- slurpy
# {'slur'} -- slurry
# {'slur'} -- slurps
# {'slur'} -- slurpee
# {'slur'} -- slurs
# {'slur'} -- slurper
# {'slur'} -- slurs==
# {'harassment', 'harass'} -- cyberharassment
# {'harassment', 'harass'} -- harassment==
# {'harassment', 'harass'} -- anti harassment
# {'harassment', 'harass'} -- wiki harassment
# {'harassment', 'harass'} -- harassement
# {'harassment', 'harass'} -- sexualharassment
# {'harassment', 'harass'} -- harassments
# {'harassment', 'harass'} -- wp:harassment
# {'obscene', 'obscen'} -- obscenely
# {'obscene', 'obscen'} -- obscenity
# {'threat'} -- cyberthreat
# {'threat'} -- altlthreat
# {'threat'} -- threatsnewl
# {'threat'} -- threath
# {'threat'} -- triplethreat
# {'threat'} -- threat==
# {'threat'} -- threats
# {'threat'} -- threatsnewlin
# {'threat'} -- threatend
# {'threat'} -- threatning
# {'threat'} -- threathening
# {'threat'} -- threaths
# {'threat'} -- threats==
# {'threat'} -- threaten
# {'threat'} -- threatening
# {'threat'} -- threatens
# {'threat'} -- threatmeter
# {'threat'} -- threathunting
# {'threat'} -- threatned
# {'threat'} -- threating
# {'discredit'} -- discreditation
# {'discredit'} -- discredits
# {'discredit'} -- discrediting
# {'hate', 'hateful'} -- hatefull
# {'hate', 'hateful'} -- hateble
# {'hate', 'hateful'} -- hatersgonnahate
# {'hate', 'hateful'} -- hatefulness
# {'hate', 'hateful'} -- hathate
# {'insult'} -- insulte
# {'insult'} -- insulter
# {'insult'} -- insultive
# {'insult'} -- insulting=guess
# {'insult'} -- insultingly
# {'insult'} -- gandinaaliinsult
# {'insult'} -- insults
# {'hostil', 'hostile'} -- `hostile
# {'hostil', 'hostile'} -- kpop hostile
# {'hostil', 'hostile'} -- hostilely
# {'hostil', 'hostile'} -- hostileenvironment
# {'taboo'} -- taboo
# {'taboo'} -- taboos
# {'taboo'} -- cmtaboo
# {'taboo'} -- tabooatpaparazzi
# {'toxic'} -- \toxic
# {'toxic'} -- nontoxic

# %%
displayDF(word_clusters)
# Out:
#         offensive          abusive   cyberbullying       vulgar  \
# 0        abrasive        insultive  cyber-bullying       bulgar
# 1       insultive       aggressive        bullying        abgar
# 2      -defensive        aggresive    antibullying     erronous
# 3        ambigous       adulterous   anti-bullying     uglydori
# 4     inadvertant      injudicious        trolling    anaerobic
# 5      attrocious          evasive       threating       slangy
# 6      derogative        obnoxious     threatening        þegar
# 7        offesive         `hostile         allying         ogar
# 8       abhorrant      insultingly        rallying         angu
# 9       obstinant    unpretentious   wiki-bullying        angus
# 10     derogatory  anti-depressant    wikibullying     mishnaic
# 11       irritant       anti-child        dallying     nastypig
# 12   prerrogative      unobtrusive         bulying       unsexy
# 13      inklusive     unprivileged         bulling   derogatory
# 14        evasive     unresponsive    anti-smoking  unoffensive
# 15  inconspicuous         abugoush         troling         slur
# 16     inc3stuous       assaultive          abhing      aerobic
# 17       obivious          anxious     bullshiting  inoffensive
# 18     insensible        obtrusive   threathunting        oleic
# 19            ant          hostile       harassing     slangin'
# 20    unconscious     kpop-hostile      threatning     sluttish
# 21       unctuous          vicious      c0rrupting     angantyr
# 22   unresponsive        malicious       disguting      insular
# 23     unconcious        persusive        trouting       slang.
# 24    derrogatory       impervious  anti-dogpiling  anglophobic
# 25        insular       mendacious      assaulting    fatphobic
# 26   misandristic         pervious        tallying      zelalic
# 27   unpersuasive        impulsive        liefting   gelatinous
# 28   anti-semetic         obivious      corrupting    offensive
# 29      offencive      anti-sexual      disobeying      yiddish
#
#               racist      homophobic          profane       slur  \
# 0         neo-facist     judeophobic  personaltrainer        slu
# 1         misogynist      xenophobic      proselytist      služi
# 2            rascist       fatphobic            profa   sluttish
# 3             facist        biphobic            prof.     slangy
# 4        anti-facist    heterophobic          prowler       slug
# 5        supremacist     lesbophobic           prof02     slushy
# 6            fascist          phobic       proszowski      sluty
# 7         mysogynist     hinduphobic  socalsupereagle    slugish
# 8   whitesupremacist     russophobic         strasser   sluggish
# 9         misoginist     iranophobic         connolly    slučaju
# 10           racisim          racist        prof.rick    slumdog
# 11       neo-fascist      homophonic          prosser   slangin'
# 12       anti-sexist      misogynist        compagnie     sluttz
# 13      clerofascist     anti-sexist        consonant      slush
# 14      nacijonalist        misogyny            prone     slutty
# 15       antifascist   #islamophobic         promjene     vulgar
# 16       nacionalist       anti-homo       con-artist   biphobic
# 17        miosgynist         \racist          prockie     slctek
# 18         racialist        anti-gay           prolly     slusho
# 19              mist    misogynistic           profar       slut
# 20            raciss         #racist        peragente      bigot
# 21       antizionist        racistly           weiter     smugly
# 22         anti-homo     anglophobic           perler     slang.
# 23      anti-zionist     anti-racist        selfpromo       slpc
# 24        misandrist    islamophobic             pron       slum
# 25       pro-fascist       nonracist        pessimist     snugly
# 26      anti-fascist       homophony         progamer       slim
# 27        liberalist  anti-pedophile           prosim  fatphobic
# 28      anti-semitic        unsexist          prosody      völur
# 29        anti-white      antiracist          dicator      slang
#
#                    harassment           obscene                 threat  \
# 0                 harrassment          en-scene                  threa
# 1                   harasment            -scene             harassment
# 2                  harrasment      hyperdescent          terror-attack
# 3                embarassment       blasphemous  excusesforthecrimein5
# 4             personalattacks     cartilaginous            harassement
# 5                 harraasment             incie              harasment
# 6                  disruption       animeatosis                  fense
# 7                    disabuse         analagous         actiontrueshot
# 8                harrassement        evanescent         idlibgasattack
# 9                     activit            oriole           embarassment
# 10                abusiveness   hemochromatosis        blockheadedness
# 11                 incivility          iptycene              unjustice
# 12                threatening            vagene        juvenilejustice
# 13                      abuse          caracter                tactile
# 14                  threating            ravage       injusticetosaint
# 15                 threatning    heteroromantic              bullycide
# 16                harrasement  uncharacteristic         counter-attack
# 17           unresponsiveness         crematory        gazaunderattack
# 18        no_personal_attacks      masturbatory            pro-offense
# 19              vandalisation       inoffensive               -defense
# 20              embarrassment            obsene            harrassment
# 21             actiontrueshot           castile            cyberattack
# 22                behaviorist             inane          counterattack
# 23             abuserdynamics        epigrapher                activit
# 24  childabusepreventionmonth          venemous                  thret
# 25             embarrassments           orioane               warcrime
# 26              cyberbullying      massagerotic         syriagasattack
# 27                     abuser       occidentale             actionshot
# 28                threatsnewl       vayathinile            attackspeed
# 29             disruptiveness  organophosphorus              injustice
#
#          discredit        hateful        insult          hostile  \
# 0            disc-    mistrustful         insul     disengenious
# 1         discrete       tolerant        excuse   immunoreactive
# 2         dicredit        fateful        assult        aggresive
# 3         disclaim  disrespectful        unmute        felonious
# 4       promulgate       trustful  insulin-like    sanctimonious
# 5       misscredit     ungrateful      embarass     disingenious
# 6         accredit    disgraceful       intrude       aggressive
# 7            disce        disgust    excuseme99      distruptive
# 8       responible        wistful     offencive  anti-depressant
# 9        co-credit  unsympathetic     embarrass     proggressive
# 10            disc       shameful      arrogate     subconscious
# 11           disc.   ohconfucious        offend    transgressive
# 12  discretisation       ignorant        attact         unactive
# 13     discrepency     ungraceful       insulin          vicious
# 14       contredit  misterpitiful       excusez   antidepressant
# 15       ignorence       spiteful         assay        torturous
# 16      condensate      #ujealous   assholemate          leprous
# 17     instantiate      stupidist   anti-semite  abusivenegative
# 18        memogate     ungracious        impugn       assaultive
# 19        disclose     ungreatful      admonish        ingenious
# 20       propigate   justtruthful     insulator     discriminant
# 21           nmate      frightful       abusive      acrimonious
# 22     remonstrate      dishonest          vult        rapacious
# 23     consentrate      sagacious    antisemite         litigant
# 24        contract     empathetic       insular       attrocious
# 25      magistrate     stupiddope       anti-se       disastrous
# 26     responcible       stupid'd    anti-flame      confrontive
# 27     pontificate        shamful      insulate           serous
# 28       prostrate        arogant    anti-semit        laborious
# 29          defame   disgusting==         idefk     disincentive
#
#                       taboo            toxic
# 0                   cariboo      /72f77gyxic
# 1                   litebay           cystic
# 2                boxinggirl       tumultuous
# 3                 chit-chat           acidic
# 4                    dingoo    heterogeneous
# 5                      spoo          #exotic
# 6                    taekey            cetic
# 7                  chitchat        synonmous
# 8                    boohoo            mimic
# 9                tattletale         sadistic
# 10  ho;ifvcgdhndashigfodsa'              uic
# 11                 ashikita     rambunctious
# 12                stonechat         neurotic
# 13        chateaubudewinery       neurogenic
# 14                  morphoo      homogeneous
# 15                    lingo        dysphoric
# 16                     taiz        unhygenic
# 17         parkinglikeatwat            nimic
# 18        horsesofinstagram          osmotic
# 19                   bamboo     neurotypical
# 20                     taik       unhygienic
# 21                   fashoo  hyper-sensitive
# 22                litterbox          bulimic
# 23                 boothang          aerobic
# 24                 plastiki         egoistic
# 25                    tasso          tantric
# 26                    footy         quixotic
# 27                tarttelin          noxious
# 28               babysitter          vacuous
# 29                    sorel             mhic

# %%
plotTSNE("Similar words - fastText [t-SNE]", word_clusters, embedding_clusters, "outputs/SimilarWords - fastText - t-SNE.png")

# %%
#plotMDS("Similar words - fastText [MDS]", word_clusters, embedding_clusters, "outputs/SimilarWords - fastText - MDS.png")

# %%
plotPCA("Similar words - fastText [PCA]", word_clusters, embedding_clusters, "outputs/SimilarWords - fastText - PCA.png")

# %% [markdown]
# #   export most similar words

# %%
# model_gn = Word2Vec.load(f"{DATASETS_FOLDER}Word2Vec_V2/w2v_50dim_model")
listOfWords = ['toxic','offensive',"abusive","cyberbullying","vulgar","racist","homophobic","profane","slur","harassment","obscene","threat","discredit","hateful","insult","hostile",'taboo']
# listOfWords = ['toxic']

# model_gnV1 = Word2Vec.load(f"C:/Users/lieb/Downloads/Word2Vec_V1/w2v_50dim_model") #V1
model_gnV1 = Word2Vec.load(f"outputs/w2v_25dim_model_v3") # v3


model_gnV2 = Word2Vec.load(f"outputs/w2v_50dim_model")
V1set = {}
V2set = {}
Uset ={}
for x in listOfWords:
    v1= set( [x[1] for x in exprtWords(x,model_gnV1)])
    v2= set( [x[1] for x in exprtWords(x,model_gnV2)])
    V1set[x] =v1.difference(v2)
    V2set[x] = v2.difference(v1)
    Uset[x] = v1.intersection(v2)
    
exportToCsv('outputs/V1set',V1set)
exportToCsv('outputs/V2set',V2set)
exportToCsv('outputs/Uset',Uset)
# model_gn = Word2Vec.load(f"outputs/w2v_50dim_model")

# %%
# model_gn = Word2Vec.load(f"outputs/w2v_50dim_model") # v1
model_gn = Word2Vec.load(f"outputs/w2v_50dim_model") # v2
# model_gn = FastText.load(f"outputs/fastText_50dim_model_v2") # v2
#from gensim.test.utils import get_tmpfile
#fname = get_tmpfile(f"outputs/fastText_50dim_model_v2")



# model = FastText.load(fname)

# model_ft = gensim.models.fasttext.load_facebook_vectors(datapath(f"outputs/fastText_50dim_model_v2.wv.vectors_ngrams.npy")) # v2
# model_gn = Word2Vec.load(f"outputs/w2v_25dim_model_v3") # v3

csvDataset = pd.read_csv(f"outputs/full_classification_dataset.csv")
